# %% [markdown]
# # Predicting Stock Price Movement with a Random Forest Classifier
# ##  Also: Backtesting
#
# As I read through the book "The Master Algorithm" by Pedro Domingos I learned that in the beginning of algorithmic trading at wallstreet, Random Forests were successfully incorperated into trading systems, aiding experienced traders in their decisions which stock to buy or sell. This sparked my interest because on the one hand, I haven't had the chance to dive deep into Random Forests and mixed with my interest in financial markets promised an interesting side-project for me. On the other hand I knew that while Random Forests have been overtaken by Neural Networks in many aspects, they can still achieve sota performance, if applied to the right task. In trading everything is about gainig alpha, that little bit of edge against the competition that lets you make smarter and more profitable decisions. To really compete, one has to find a niche that suits ones trading strategy, and maybe a Random Forest on just the right indicators could be my edge. One can dream, anyhow.
#
# This is serves more as a showcase of a backtesting pipeline, as I'm not going to write yet another blog post explaining what Random Forests are or how to calculate basic trading indicators. There are literally hundred of these already, besides of course the literature, which I'm sure does a better job explaining than I could. The Pipeline is straight forward, and comments should be enough to give insight into more complicated code.
#
# ### Content
# 1. Data Preparation
# 2. Calculating Indicators
# 3. Model Fit
# 4. First Metrics
# 5. Backtesting
# 6. What Now?

# %%
"""The usual Imports"""
import ast
import time
import pandas as pd
from datetime import date, timedelta, datetime
import math
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /Users/max/.pyenv/versions/3.8.5/lib/python3.8/site-packages/pandas/compat/__init__.py:97: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %% [markdown]
# ## 1. Data Preparation
#
# Two Files are needed:
# tickers_and_sectors is a file I composed of a public available list of nasdaq tickers. As the name suggest, I only needed the ticker (Name of a stock) and its sector (e.g. Technology).
#
# Historical Data. Obviously. Taken from yahoo finance with yfinance lib. Can stem from where-ever.

# %%
"""Tickers and Sectors"""

with open('tickers_and_sectors.txt', 'r') as f:
    tickers_and_sectors = ast.literal_eval(f.readlines()[0])

# Dict that sorts tickers by sector
tickers_by_sector = {}

for ticker, sector in tickers_and_sectors.items():
    if sector in tickers_by_sector:
        tickers_by_sector[sector].append(ticker)
    else:
        tickers_by_sector[sector] = [ticker]
        

"""Historical Data"""
start = time.time()

data = pd.read_csv('10_year_all_tickers', index_col=[0], header=[0,1])

end = time.time()
print("this took {} seconds".format(end-start))

data[:5]
# Out:
# this took 38.116071939468384 seconds
#                 AACG                                        AACQ             \
#            Adj Close Close  High   Low  Open    Volume Adj Close Close High
# Date
# 2011-03-16  0.650397  8.10  8.25  7.69  7.71  158900.0       NaN   NaN  NaN
# 2011-03-17  0.649594  8.09  8.60  7.84  8.41   49200.0       NaN   NaN  NaN
# 2011-03-18  0.641565  7.99  8.10  7.68  8.10   18100.0       NaN   NaN  NaN
# 2011-03-21  0.635141  7.91  8.00  7.80  8.00   14700.0       NaN   NaN  NaN
# 2011-03-22  0.635141  7.91  8.00  7.86  8.00    4800.0       NaN   NaN  NaN
#
#                 ... ZYNE                      ZYXI                          \
#            Low  ... High Low Open Volume Adj Close Close  High   Low  Open
# Date            ...
# 2011-03-16 NaN  ...  NaN NaN  NaN    NaN       NaN   NaN   NaN   NaN   NaN
# 2011-03-17 NaN  ...  NaN NaN  NaN    NaN  0.408047  0.75  0.75  0.75  0.75
# 2011-03-18 NaN  ...  NaN NaN  NaN    NaN  0.408047  0.75  0.75  0.75  0.75
# 2011-03-21 NaN  ...  NaN NaN  NaN    NaN  0.408047  0.75  0.75  0.75  0.75
# 2011-03-22 NaN  ...  NaN NaN  NaN    NaN  0.408047  0.75  0.75  0.75  0.75
#
#
#             Volume
# Date
# 2011-03-16     NaN
# 2011-03-17  9000.0
# 2011-03-18  6500.0
# 2011-03-21  8600.0
# 2011-03-22   100.0
#
# [5 rows x 22644 columns]

# %%
"""
This cell gets rid of the multihierarchical index and sorts by ticker, rather than by date. This is needed for indicator calculation.
"""

start = time.time()
adj = data.T.melt(value_name='Adj Close', ignore_index=False).xs('Adj Close', level=1)
adj.index.name = 'Symbol'
adj = adj.sort_values(['Symbol', 'Date']).reset_index()

close = data.T.melt(value_name='Close', ignore_index=False).xs('Close', level=1)
close.index.name = 'Symbol'
close = close.sort_values(['Symbol', 'Date']).reset_index()

high = data.T.melt(value_name='High', ignore_index=False).xs('High', level=1)
high.index.name = 'Symbol'
high = high.sort_values(['Symbol', 'Date']).reset_index()

low = data.T.melt(value_name='Low', ignore_index=False).xs('Low', level=1)
low.index.name = 'Symbol'
low = low.sort_values(['Symbol', 'Date']).reset_index()

_open = data.T.melt(value_name='Open', ignore_index=False).xs('Open', level=1)
_open.index.name = 'Symbol'
_open = _open.sort_values(['Symbol', 'Date']).reset_index()

vol = data.T.melt(value_name='Volume', ignore_index=False).xs('Volume', level=1)
vol.index.name = 'Symbol'
vol = vol.sort_values(['Symbol', 'Date']).reset_index()

#ToDo give cleaned another name
cleaned = pd.merge(adj, close, how='inner', left_on=['Date', 'Symbol'], right_on=['Date', 'Symbol'])
cleaned = pd.merge(cleaned, high, how='inner', left_on=['Date', 'Symbol'], right_on=['Date', 'Symbol'])
cleaned = pd.merge(cleaned, low, how='inner', left_on=['Date', 'Symbol'], right_on=['Date', 'Symbol'])
cleaned = pd.merge(cleaned, _open, how='inner', left_on=['Date', 'Symbol'], right_on=['Date', 'Symbol'])
cleaned = pd.merge(cleaned, vol, how='inner', left_on=['Date', 'Symbol'], right_on=['Date', 'Symbol'])

end = time.time()

print("this took {} seconds".format(end-start))
cleaned
# Out:
# this took 70.4691858291626 seconds
#         Symbol        Date  Adj Close      Close       High        Low  \
# 0         AACG  2011-03-16   0.650397   8.100000   8.250000   7.690000
# 1         AACG  2011-03-17   0.649594   8.090000   8.600000   7.840000
# 2         AACG  2011-03-18   0.641565   7.990000   8.100000   7.680000
# 3         AACG  2011-03-21   0.635141   7.910000   8.000000   7.800000
# 4         AACG  2011-03-22   0.635141   7.910000   8.000000   7.860000
# ...        ...         ...        ...        ...        ...        ...
# 9514249   ZYXI  2021-03-10  16.740000  16.740000  17.799999  16.610001
# 9514250   ZYXI  2021-03-11  16.980000  16.980000  17.110001  16.370001
# 9514251   ZYXI  2021-03-12  16.870001  16.870001  16.959999  16.549999
# 9514252   ZYXI  2021-03-15  16.330000  16.330000  17.030001  16.129999
# 9514253   ZYXI  2021-03-16        NaN        NaN        NaN        NaN
#
#               Open    Volume
# 0         7.710000  158900.0
# 1         8.410000   49200.0
# 2         8.100000   18100.0
# 3         8.000000   14700.0
# 4         8.000000    4800.0
# ...            ...       ...
# 9514249  17.600000  556200.0
# 9514250  16.820000  518100.0
# 9514251  16.879999  421500.0
# 9514252  16.809999  463200.0
# 9514253        NaN       NaN
#
# [9514254 rows x 8 columns]

# %%
"""
From now on I rely on numpy arrays, as they work much quicker on this scale than pandas, as countless posts prove.
We're working with 10 years of dayily trading data for well above 3000 tickers.

Order of columns: ['ticker', 'date', 'adjclose', 'close', 'high', 'low', 'open', 'volume']
"""

np_data = cleaned.to_numpy()
np_data.shape
# Out:
# (9514254, 8)

# %% [markdown]
# ## 2. Caluclating Technical Indicators
#
# 1. Change of Price (cop) & boolean for up-days
# 2. Relative Strength Indicator (rsi) & Exponentially Weighted Moving Average (ewma)
# 3. On-Balance Volume (obv)
# 4. Adding Prediction Column and cleaning data from NaN-Values
# 5. Sector indicators.
#
# All of these are calculated in a separate cell. In a bigger systems one should of course look to minimize time spent, packing as much as possible in a single loop while maintaing read-, and scaleability.

# %%
"""
Calculating change in price together with up days (days which closed above their open price)
"""

# used only once, outcomment
np_data = np.hstack((np_data, np.ones((np_data.shape[0],2))))

start = time.time()
for i in range(np_data.shape[0]):
    cop = np_data[i][6] - np_data[i][3]
    np_data[i][8] = cop
    if cop < 0:
        np_data[i][9] = 0

end = time.time()    
print("This took {} seconds".format(end-start))
#print_lines(np_data,20)
# Out:
# This took 7.517102241516113 seconds

# %%
"""
Calculating Relative Strength Indicator
For the rsi required ewma for up-days and down-days are also used as separate indicators. Later we'll think about this again.
"""

# used only once, outcomment
np_data = np.hstack((np_data, np.ones((np_data.shape[0],3))))

#variables
alpha = 0.82
window_size = 14
#alpha = 2 / (window_size + 1.0)
up_day = 0 
cop = 0.0 # change of price
ewma_up, ewma_down = 0.0, 0.0

start_time = time.time()

for i, row in enumerate(np_data):
    #print(row, i)
    cop = 0 if np.isnan(row[8]) else row[8]
    up_day = row[9]
    
    # THINK ABOUT IT: does it make sense to add ewma up and down as seperate indicator, or does this introduce a stronger bias because
    # rsi already incoperates them? d
    if up_day == 1:
        ewma_up = alpha * cop + (1-alpha) * ewma_up
        row[11] = ewma_up
        
    else:
        ewma_down = alpha * (-cop) + (1-alpha) * ewma_up
        row[12] = ewma_down
             
    if i >= window_size:
        #print(ewma_down, ewma_up)
        try:
            row[10] = 100 - (100/ (1+ ewma_up/ewma_down))
        except ZeroDivisionError as err:
            row[10] = 0
            #print("Handling runtime error, rsi set to 0", err)
    
    try:
        if row[0] != np_data[i+1][0]:
            #print('New Ticker, time until now: {} sec.'.format(time.time()-start_time))
            ewma_up, ewma_down = 0, 0
    except IndexError as err:
        print("Finished with last index check out of bounds", err)

print("This took {} seconds".format(time.time()-start_time))
# Out:
# Finished with last index check out of bounds index 9514254 is out of bounds for axis 0 with size 9514254
# This took 22.63750410079956 seconds

# %%
"""
Calculating On-Balance Volume Indicator
"""

# used only once, outcomment
np_data = np.hstack((np_data, np.ones((np_data.shape[0],1))))


# variables
obv = 0 #on balance volume
volume = 0
up_day = 0

start_time = time.time()

for i, row in enumerate(np_data):
    #print(row, i)
    volume = 0 if np.isnan(row[7]) else row[7] 
    up_day = row[9]
    
    if up_day == 1:
        obv += volume
    else:
        obv -= volume
    
    row[-1] = obv
    
    try:
        if row[0] != np_data[i+1][0]:
            #print('New Ticker, time until now: {} sec.'.format(time.time()-start_time))
            obv = 0
    except IndexError as err:
        print("Finished with last index check out of bounds", err)
            
print("This took {} seconds".format(time.time()-start_time))
# Out:
# Finished with last index check out of bounds index 9514254 is out of bounds for axis 0 with size 9514254
# This took 17.308608055114746 seconds

# %%
"""
Adding Prediction Column
"""

# used only once, outcomment
# we add two columns here, because we want two extra for sector indices,
# which will be only added after another resort
np_data = np.hstack((np_data, np.zeros((np_data.shape[0],3))))


start_price, cur_price = 0, 0
time_span = 14

start_time = time.time()

for i, row in enumerate(np_data):
    if i+time_span >= np_data.shape[0]: break
        
    start_price = row[3]
    
    for j in range(time_span):
        cur_price = np_data[i+j][3]
        
        if cur_price >= (start_price * 1.15):
            np_data[i][-1] = 1
            
print("This took {} sec".format(time.time()-start_time))
# Out:
# This took 53.224575996398926 sec

# %%
"""
Sorting and Cleaning the data from NaN values
"""

import math

# Sort data for dates
np_data = np_data[np_data[:, 1].argsort()]

# Clean data from NaN values
cleaned_data = []

start = time.time()

for row in np_data:
    no_nan = True
    for ele in row[2:]:
        if math.isnan(ele):
            no_nan = False
            break
    if no_nan:
        cleaned_data.append(row)
        
print("This took {} secs".format(time.time()- start))        
cleaned_data = np.asarray(cleaned_data)
cleaned_data.shape
# Out:
# This took 24.340319871902466 secs
# (5319966, 17)

# %%
"""
Sector indicators
Go through all tickers for one day, sum up the relevant values,
then reiterate through the day and fill in the result.

Requires data sorted by dates
"""

for sector, ticker_list in tickers_by_sector.items():
    idx = 0
    k = 0
    count_fin = False
    sector_updays = 0
    sector_ewma = 0
    n_tickers = len(ticker_list)
    
    pre_date = cleaned_data[0,1]
    
    print(sector)
    while idx < cleaned_data.shape[0]:
        row = cleaned_data[idx]
        ticker = row[0]
        date = row[1]
        #print(pre_date, date)
        # Summed all relevant vals of one day, now fill them in
        if date != pre_date and not count_fin:
            idx -= k
            count_fin = True
            #print(idx)
            continue
            
        # Do for one day:
        if ticker in ticker_list and not count_fin:
            
            up_day = row[9]
            sector_ewma = row[11] + row[12]
            
            if up_day:
                sector_updays += 1
            else:
                sector_updays -= 1
            #if sector_updays != 0:
                #print("here")
        
        if count_fin and ticker in ticker_list:
            cleaned_data[idx][-3] = sector_updays
            cleaned_data[idx][-2] = sector_ewma / n_tickers
            #row[-2] = sector_updays #because last row is already prediction row
            
        k += 1    
        # Next Day Begins
        if count_fin and date != pre_date:
            count_fin = False
            sector_updays = 0
            k = 0
        idx += 1
        pre_date = date
# Out:
# Consumer Defensive
# Industrials
# Financial Services
# Technology
# Healthcare
# Communication Services
# Utilities
#
# Real Estate
# Energy
# Basic Materials
# Consumer Cyclical
# Services

# %% [markdown]
# Indicators are the vital part of a algorithmic trading strategy. You have to carefully pick a combination that you think will fit your strategy well, indicators that can work together and yield new information not only about the present day, but which also allow a look into the past. Dont forget to keep an eye out for the bigger picture, with sector indices providing a birds eye view of the current market sentiment. Of course one can go absolutely haywire and stuff as many indicators into a system as possible, but I believe in simplicity, price action and volume. Therefore I picked just a few indicators that support my view. While these are not all that I used over the course of the project, they are some of the most important ones.

# %%
raise Exception("You will not pass!")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-12-246dddc9fed0> in <module>
# ----> 1 raise Exception("You will not pass!")
#
# Exception: You will not pass!

# %% [markdown]
# ## 3. Model Fit

# %%
from sklearn.model_selection import train_test_split

X_cols = cleaned_data[:,2:-1].astype('float64')
#X_cols = numerical_data[:,:6]
Y_cols = cleaned_data[:,-1].astype('float64')

X_train, X_test, y_train, y_test = train_test_split(X_cols, Y_cols, train_size=0.6, random_state = 0)
print("X_train: {}, X_test: {}, y_train: {}, y_test: {}".format(X_train.shape, X_test.shape, y_train.shape, y_test.shape))
# Out:
# X_train: (3191979, 14), X_test: (2127987, 14), y_train: (3191979,), y_test: (2127987,)

# %%
from sklearn.ensemble import RandomForestClassifier

forest = RandomForestClassifier(n_estimators = 100,  criterion = "gini", random_state = 0)#oob_score = True,

start = time.time()

# Fit the data to the model
forest.fit(X_train, y_train)
#forest.fit(sampl, y_train_t)
#forest.fit(X_train[:10], y_train[:10])
#forest.fit(np.random.random_sample((3989,11)), y_train[:3989])

print("This took {} secs".format(time.time()-start))

# %%
import joblib
# save
joblib.dump(forest, "eng_10y_sector_trainsize06.joblib", compress=3)

# %% [markdown]
# eng trained on all rows sector forest, tested on german test data:
#     Of the correct predictions, we have 1408 positives and 309284 negatives
#     Of the incorrect predictions, we have 4723 positives and 26631 negatives
#
# eng trained on all rows sector forest, tested on german train data:
#     Of these correct predictions, we have 4171 positives and 927940 negatives
#     Of the incorrect predictions, we have 13979 positives and 80047 negatives
#
# eng trained price action solo indicators, tested on german test data:
#     Of these correct predictions, we have 1399 positives and 309330 negatives
#     Of the incorrect predictions, we have 4677 positives and 26640 negatives

# %%
sampl = np.random.uniform(low=2.42, high=1337.42, size=(150000,5))

# %%
y_train.shape

# %%
y_pred = forest.predict(X_test)

total_cor, total = 0, 0
total_true_pos, total_true_neg = 0, 0
total_false_pos, total_false_neg = 0, 0

for pred, target in zip(y_pred, y_test):
    total += 1
    if pred == target:
        total_cor += 1
        
        if target == 0: total_true_neg += 1
        else: total_true_pos += 1
    elif pred == 0:
        total_false_neg += 1
    else: total_false_pos += 1

# %%
print("{} were correct predictions, yielding an accuracy of {}%.".format(total_cor, (total_cor/total)*100))
print("Of the correct predictions, we have {} positives and {} negatives".format(total_true_pos, total_true_neg))
print("Of the incorrect predictions, we have {} positives and {} negatives".format(total_false_pos, total_false_neg))

# %%
total_cor, total = 0, 0

for i, rows in enumerate(zip(X_test, y_test)):
    x_row, y_row = rows[0], rows[1]
    
    y_pred = forest.predict(x_row.reshape(1, -1))
    
    if y_pred == y_row:
        total_cor += 1
        print("Correct predicted row: ", x_row)
    else:
        print("Incorrectly predicted row: ", x_row)

# %% [markdown]
# ### Save the model with joblib dump

# %%
import joblib
# save
#joblib.dump(forest, "german_no_sector_forest.joblib", compress=3) #without compress its 6 gb big :D 

#to load:
forest = joblib.load("eng_10y_sector_trainsize06.joblib")

# %% [markdown]
# ## Backtesting with budget

# %%
cleaned_data[389589]

# %%
import backtest

# Trade Attributes
total_n_trades = 0
total_n_trades_won = 0
total_n_trades_lost = 0
total_sum_trades_won = 0
total_sum_trades_lost = 0

total_average_gain = 0
total_average_loss = 0
total_total_profit = 0


# dict of all currently held stocks
held = {}
# dict of all buys of one stock
bought = {}
# dict of all sells of one stock
sold = {}
# dict of all profits of one day
profit_per_day = {}
total_revenue = 0

bet_percent = 0.12
budget = 30000
#bet_size = backtest.calc_bet_size(budget, bet_percent)

start = time.time()
old_date = 0

for row in cleaned_data[X_train.shape[0]+1727987:,]:
#for row in cleaned_data[-250000:,]:
#for row in test_t:
    ticker, date = row[0], row[1]
    data = row[2:-1] #2 if adj close should be incoperated
    bet_size = budget * bet_percent
    
    #if old_date != date:
        #print("\n###################\n     One day takes", time.time()-start)
        #print("################")
    old_date = date
    
    # Before buying, make sure ticker is not already bought
    # If already bought, check for a sell signal
    if ticker in held.keys():
        n_shares, held_data = held[ticker]

        # held_data[1] is close price
        if backtest.is_sell(held_data[1], data[1]):
            _, negative = backtest.is_sell(held_data[1], data[1]) # change two lines so you only need function call once
            revenue, profit, budget = backtest.sell(entry_ticker_close=held_data[1], cur_ticker_close=data[1],
                                           n_shares=n_shares, budget=budget, neg=negative, perfect=False)

            if negative:
                total_n_trades_lost += 1
                total_sum_trades_lost -= profit
            else:
                total_n_trades_won += 1
                total_sum_trades_won += profit

            del held[ticker]
            print("\nSold {} at {} for a profit of {:4f} returning {} as revenue".format(ticker, date,
                                                                                         profit, revenue))
            print("New budget: ", budget)
            
    
    # buy ticker
    #ToDo maybe input lag in buying, say one stock thas has been sold cant be rebought for one month
    elif backtest.is_buy(data, forest): # shouldnt hit if ticker is sold the same day
        if budget > 10000:
            print("\nBought ", ticker, " at ", date, end=" ")
            n_shares, left_over_bet, budget = backtest.buy(share_price= data[1],
                                                          bet_size=bet_size, budget = budget)
            held[ticker] = (n_shares, data)
            print("for {} n shares with per share price: {:4f}, totaling: {:4f}".format(n_shares, data[1],
                                                                                        n_shares*data[1]))
            print("New budget is: ", budget)
            
    
            
print("This took {} secs".format(time.time()-start))
print("Final budget is: ", budget)

money_held = 0
for n_shares, data in held.values():
    money_held += n_shares * data[1]
print("Money still held: ", money_held)

# %%
len(held.values())

# %%
for t in held.items():
    print(t)

# %%
print(cleaned_data[3989975])
print(date)

# %%
print("This took {} secs".format(time.time()-start))
print("Final budget is: ", budget)

money_held = 0
for ticker, (n_shares, data) in held.items():
    #print(ticker, n_shares)
    money_held += n_shares * data[1]
print("Money still held: ", money_held)

# %%
total_n_trades_lost

# %%
total_n_trades_won

# %%
len(held.keys())

# %%
total_sum_trades_lost

# %%
total_sum_trades_won

# %%
pd.Series(forest.feature_importances_, index=['adjclose', 'close', 'high', 'low', 'open', 'volume', 'cop', 'upday', 
                                              'rsi', 'ewma_up', 'ewma_down', 'obv', 'sector_up', 'sector_ewma']).sort_values(ascending=False)

# %% [markdown]
# ## Test with fewer tickers
#
# Now we want to run our test with tickers from the s&p 500. This will show us what happens in backtesting when restricting number of tickers and let us make an educated guess which ticker have more impact with the performance of the model. S&P 500 consists of the strongest tickers in the US-market, especially in the tech-sector. With this we can estimate if our model mainly relies on established and well performing tickers, or if it makes heavy use of smaller, more under-the-radar tickers.

# %%
sp500_data = pd.read_csv('s&p500_constituents_csv.csv', header=[0])
print(sp500_data.head())
sp500_tickers = sp500_data['Symbol'].to_list()
# Out:
#   Symbol                 Name       Sector
# 0    MMM                   3M  Industrials
# 1    AOS          A. O. Smith  Industrials
# 2    ABT  Abbott Laboratories  Health Care
# 3   ABBV               AbbVie  Health Care
# 4   ABMD              Abiomed  Health Care

# %%
import backtest

# Trade Attributes
total_n_trades = 0
total_n_trades_won = 0
total_n_trades_lost = 0
total_sum_trades_won = 0
total_sum_trades_lost = 0

total_average_gain = 0
total_average_loss = 0
total_total_profit = 0


# dict of all currently held stocks
held = {}
# dict of all buys of one stock
bought = {}
# dict of all sells of one stock
sold = {}
# dict of all profits of one day
profit_per_day = {}
total_revenue = 0

bet_percent = 0.12
budget = 30000
#bet_size = backtest.calc_bet_size(budget, bet_percent)

start = time.time()
old_date = 0

for row in cleaned_data[X_train.shape[0]+1727987:,]:
#for row in cleaned_data[-250000:,]:
#for row in test_t:
    ticker, date = row[0], row[1]
    
    if ticker not in sp500_tickers:
        continue
        
    data = row[2:-1] #2 if adj close should be incoperated
    bet_size = budget * bet_percent
    
    #if old_date != date:
        #print("\n###################\n     One day takes", time.time()-start)
        #print("################")
    old_date = date
    
    # Before buying, make sure ticker is not already bought
    # If already bought, check for a sell signal
    if ticker in held.keys():
        n_shares, held_data = held[ticker]

        # held_data[1] is close price
        if backtest.is_sell(held_data[1], data[1]):
            _, negative = backtest.is_sell(held_data[1], data[1]) # change two lines so you only need function call once
            revenue, profit, budget = backtest.sell(entry_ticker_close=held_data[1], cur_ticker_close=data[1],
                                           n_shares=n_shares, budget=budget, neg=negative, perfect=False)

            if negative:
                total_n_trades_lost += 1
                total_sum_trades_lost -= profit
            else:
                total_n_trades_won += 1
                total_sum_trades_won += profit

            del held[ticker]
            print("\nSold {} at {} for a profit of {:4f} returning {} as revenue".format(ticker, date,
                                                                                         profit, revenue))
            print("New budget: ", budget)
            
    
    # buy ticker
    #ToDo maybe input lag in buying, say one stock thas has been sold cant be rebought for one month
    elif backtest.is_buy(data, forest): # shouldnt hit if ticker is sold the same day
        if budget > 10000:
            print("\nBought ", ticker, " at ", date, end=" ")
            n_shares, left_over_bet, budget = backtest.buy(share_price= data[1],
                                                          bet_size=bet_size, budget = budget)
            held[ticker] = (n_shares, data)
            print("for {} n shares with per share price: {:4f}, totaling: {:4f}".format(n_shares, data[1],
                                                                                        n_shares*data[1]))
            print("New budget is: ", budget)
            
    
            
print("This took {} secs".format(time.time()-start))
print("Final budget is: ", budget)

money_held = 0
for n_shares, data in held.values():
    money_held += n_shares * data[1]
print("Money still held: ", money_held)
# Out:
# Bought  ENPH  at  2020-09-17 for 53 n shares with per share price: 66.870003, totaling: 3544.110146
# New budget is:  26455.88985
#
# Bought  ETSY  at  2020-09-17 for 29 n shares with per share price: 109.230003, totaling: 3167.670097
# New budget is:  23288.219748
#
# Bought  MKTX  at  2020-09-18 for 6 n shares with per share price: 438.660004, totaling: 2631.960022
# New budget is:  20656.25972824
#
# Bought  AMD  at  2020-09-18 for 33 n shares with per share price: 74.930000, totaling: 2472.690010
# New budget is:  18183.5697208512
#
# Bought  MPWR  at  2020-09-18 for 8 n shares with per share price: 253.940002, totaling: 2031.520020
# New budget is:  16152.049704349056
#
# Bought  CDW  at  2020-09-21 for 17 n shares with per share price: 108.809998, totaling: 1849.769958
# New budget is:  14302.27974982717
#
# Bought  ILMN  at  2020-09-22 for 6 n shares with per share price: 268.510010, totaling: 1611.060059
# New budget is:  12691.219689847909
#
# Bought  SIVB  at  2020-09-22 for 6 n shares with per share price: 230.470001, totaling: 1382.820007
# New budget is:  11308.39968706616
#
# Bought  KLAC  at  2020-09-22 for 7 n shares with per share price: 183.300003, totaling: 1283.100021
# New budget is:  10025.29966461822
#
# Bought  FITB  at  2020-09-22 for 59 n shares with per share price: 20.110001, totaling: 1186.490036
# New budget is:  8838.809624864034
#
# Sold ENPH at 2020-09-28 for a profit of 358.385892 returning 3902.4960419999998 as revenue
# New budget:  12741.305666864035
#
# Bought  TROW  at  2020-09-29 for 11 n shares with per share price: 127.489998, totaling: 1402.389977
# New budget is:  11338.91568684035
#
# Bought  EXC  at  2020-09-29 for 38 n shares with per share price: 35.320000, totaling: 1342.159988
# New budget is:  9996.755694419508
#
# Sold ILMN at 2020-09-30 for a profit of 146.051916 returning 1757.1119760000001 as revenue
# New budget:  11753.867670419508
#
# Bought  ENPH  at  2020-09-30 for 17 n shares with per share price: 82.589996, totaling: 1404.029938
# New budget is:  10349.837729969167
#
# Bought  ZBRA  at  2020-09-30 for 4 n shares with per share price: 252.460007, totaling: 1009.840027
# New budget is:  9339.997702372866
#
# Sold ETSY at 2020-10-01 for a profit of 390.803982 returning 3558.4740819999997 as revenue
# New budget:  12898.471784372865
#
# Bought  XLNX  at  2020-10-02 for 15 n shares with per share price: 102.589996, totaling: 1538.849945
# New budget is:  11359.62184024812
#
# Bought  APA  at  2020-10-02 for 139 n shares with per share price: 9.740000, totaling: 1353.859968
# New budget is:  10005.761869418346
#
# Sold CDW at 2020-10-05 for a profit of 174.113994 returning 2023.883954 as revenue
# New budget:  12029.645823418345
#
# Bought  ALGN  at  2020-10-05 for 4 n shares with per share price: 319.510010, totaling: 1278.040039
# New budget is:  10751.605784608142
#
# Sold ENPH at 2020-10-05 for a profit of 157.692066 returning 1561.722006 as revenue
# New budget:  12313.327790608142
#
# Bought  HSIC  at  2020-10-06 for 25 n shares with per share price: 58.840000, totaling: 1471.000004
# New budget is:  10842.327785735164
#
# Bought  IPGP  at  2020-10-06 for 7 n shares with per share price: 173.970001, totaling: 1217.790009
# New budget is:  9624.537781446945
#
# Sold SIVB at 2020-10-07 for a profit of 129.815988 returning 1512.6359980000002 as revenue
# New budget:  11137.173779446945
#
# Sold MKTX at 2020-10-07 for a profit of 257.652030 returning 2889.6120499999997 as revenue
# New budget:  14026.785829446944
#
# Sold AMD at 2020-10-07 for a profit of 232.848042 returning 2705.538052 as revenue
# New budget:  16732.323881446944
#
# Sold FITB at 2020-10-07 for a profit of 113.987976 returning 1300.478016 as revenue
# New budget:  18032.801897446945
#
# Sold MPWR at 2020-10-07 for a profit of 213.024024 returning 2244.5440439999998 as revenue
# New budget:  20277.345941446943
#
# Sold KLAC at 2020-10-09 for a profit of 116.507958 returning 1399.607978 as revenue
# New budget:  21676.953919446943
#
# Sold XLNX at 2020-10-09 for a profit of 165.150054 returning 1704.000004 as revenue
# New budget:  23380.953923446945
#
# Sold EXC at 2020-10-13 for a profit of 129.047994 returning 1471.2079840000001 as revenue
# New budget:  24852.161907446945
#
# Sold APA at 2020-10-13 for a profit of -83.399920 returning 1270.46005 as revenue
# New budget:  26122.621957446947
#
# Sold TROW at 2020-10-15 for a profit of 128.040006 returning 1530.4299859999999 as revenue
# New budget:  27653.051943446946
#
# Sold ZBRA at 2020-10-16 for a profit of 97.295982 returning 1107.1360120000002 as revenue
# New budget:  28760.187955446945
#
# Bought  SIVB  at  2020-10-19 for 12 n shares with per share price: 270.630005, totaling: 3247.560059
# New budget is:  25512.62790079331
#
# Bought  WYNN  at  2020-10-19 for 43 n shares with per share price: 69.669998, totaling: 2995.809921
# New budget is:  22516.817982698118
#
# Bought  GRMN  at  2020-10-19 for 27 n shares with per share price: 97.720001, totaling: 2638.440033
# New budget is:  19878.377944774344
#
# Bought  GOOGL  at  2020-10-19 for 1 n shares with per share price: 1529.949951, totaling: 1529.949951
# New budget is:  18348.427991401422
#
# Bought  ZBRA  at  2020-10-19 for 7 n shares with per share price: 291.570007, totaling: 2040.990051
# New budget is:  16307.437942433251
#
# Bought  TECH  at  2020-10-20 for 7 n shares with per share price: 264.489990, totaling: 1851.429932
# New budget is:  14456.008009341262
#
# Bought  XLNX  at  2020-10-20 for 15 n shares with per share price: 114.730003, totaling: 1720.950050
# New budget is:  12735.05795822031
#
# Bought  HOLX  at  2020-10-20 for 23 n shares with per share price: 66.379997, totaling: 1526.739937
# New budget is:  11208.318023233873
#
# Bought  BIIB  at  2020-10-20 for 5 n shares with per share price: 267.119995, totaling: 1335.599976
# New budget is:  9872.718050445808
#
# Sold ALGN at 2020-10-22 for a profit of 320.928000 returning 1598.9680399999997 as revenue
# New budget:  11471.686090445808
#
# Bought  LRCX  at  2020-10-22 for 3 n shares with per share price: 358.010010, totaling: 1074.030029
# New budget is:  10397.656059592311
#
# Bought  MAR  at  2020-10-22 for 12 n shares with per share price: 100.820000, totaling: 1209.839996
# New budget is:  9187.816062441234
#
# Sold IPGP at 2020-10-23 for a profit of 110.081964 returning 1327.871974 as revenue
# New budget:  10515.688036441234
#
# Bought  NWS  at  2020-10-23 for 90 n shares with per share price: 13.910000, totaling: 1251.899986
# New budget is:  9263.788052068285
#
# Sold HSIC at 2020-10-23 for a profit of 134.250012 returning 1605.250012 as revenue
# New budget:  10869.038064068285
#
# Bought  TRMB  at  2020-10-23 for 26 n shares with per share price: 50.080002, totaling: 1302.080048
# New budget is:  9566.958016380091
#
# Sold MAR at 2020-10-27 for a profit of -88.320010 returning 1121.51999 as revenue
# New budget:  10688.478006380092
#
# Bought  MRNA  at  2020-10-27 for 18 n shares with per share price: 70.669998, totaling: 1272.059967
# New budget is:  9416.41803561448
#
# Sold LRCX at 2020-10-28 for a profit of -57.330050 returning 1016.69998 as revenue
# New budget:  10433.11801561448
#
# Bought  CTAS  at  2020-10-28 for 3 n shares with per share price: 315.540009, totaling: 946.620026
# New budget is:  9486.497993740742
#
# Sold BIIB at 2020-10-28 for a profit of -114.300010 returning 1221.29997 as revenue
# New budget:  10707.797963740742
#
# Bought  TMUS  at  2020-10-28 for 11 n shares with per share price: 109.800003, totaling: 1207.800034
# New budget is:  9499.997928091854
#
# Sold MRNA at 2020-10-28 for a profit of -88.740010 returning 1183.31996 as revenue
# New budget:  10683.317888091855
#
# Bought  MAR  at  2020-10-28 for 14 n shares with per share price: 89.970001, totaling: 1259.580017
# New budget is:  9423.737871520832
#
# Sold NWS at 2020-10-28 for a profit of -92.699980 returning 1159.20001 as revenue
# New budget:  10582.937881520833
#
# Bought  KLAC  at  2020-10-29 for 6 n shares with per share price: 201.949997, totaling: 1211.699982
# New budget is:  9371.237895738333
#
# Sold SIVB at 2020-11-05 for a profit of 302.688060 returning 3550.2481199999997 as revenue
# New budget:  12921.486015738334
#
# Sold TECH at 2020-11-05 for a profit of 168.462066 returning 2019.8919960000003 as revenue
# New budget:  14941.378011738334
#
# Bought  PFG  at  2020-11-05 for 41 n shares with per share price: 43.009998, totaling: 1763.409931
# New budget is:  13177.968080329734
#
# Sold GRMN at 2020-11-05 for a profit of 251.909928 returning 2890.349958 as revenue
# New budget:  16068.318038329733
#
# Bought  NTAP  at  2020-11-05 for 41 n shares with per share price: 46.709999, totaling: 1915.109962
# New budget is:  14153.208073730166
#
# Bought  AAL  at  2020-11-05 for 146 n shares with per share price: 11.600000, totaling: 1693.600056
# New budget is:  12459.608014882546
# Bought  DISCA  at  2020-11-05 for 69 n shares with per share price: 21.430000, totaling: 1478.670021
# New budget is:  10980.93799309664
#
# Sold WYNN at 2020-11-05 for a profit of 269.867976 returning 3265.677896 as revenue
# New budget:  14246.61588909664
#
# Bought  NTRS  at  2020-11-05 for 20 n shares with per share price: 81.580002, totaling: 1631.600037
# New budget is:  12615.015852405044
#
# Sold GOOGL at 2020-11-05 for a profit of 139.530030 returning 1669.4799799999998 as revenue
# New budget:  14284.495832405044
#
# Bought  AMAT  at  2020-11-05 for 24 n shares with per share price: 69.949997, totaling: 1678.799927
# New budget is:  12605.69590251644
#
# Bought  CZR  at  2020-11-05 for 26 n shares with per share price: 56.130001, totaling: 1459.380028
# New budget is:  11146.315874214468
#
# Sold HOLX at 2020-11-05 for a profit of 142.002012 returning 1668.7419519999999 as revenue
# New budget:  12815.057826214468
#
# Bought  APA  at  2020-11-05 for 171 n shares with per share price: 8.970000, totaling: 1533.870046
# New budget is:  11281.187777068733
#
# Bought  DLTR  at  2020-11-05 for 14 n shares with per share price: 95.099998, totaling: 1331.399979
# New budget is:  9949.787793820486
#
# Sold ZBRA at 2020-11-05 for a profit of 203.909952 returning 2244.900002 as revenue
# New budget:  12194.687795820486
#
# Bought  MRNA  at  2020-11-05 for 20 n shares with per share price: 71.480003, totaling: 1429.600067
# New budget is:  10765.087730322028
#
# Bought  HST  at  2020-11-05 for 118 n shares with per share price: 10.930000, totaling: 1289.740036
# New budget is:  9475.347692683385
#
# Sold XLNX at 2020-11-06 for a profit of 174.509928 returning 1895.4599779999999 as revenue
# New budget:  11370.807670683385
#
# Bought  SIVB  at  2020-11-06 for 4 n shares with per share price: 313.369995, totaling: 1253.479980
# New budget is:  10117.327690201379
#
# Bought  WBA  at  2020-11-06 for 32 n shares with per share price: 37.310001, totaling: 1193.920044
# New budget is:  8923.407647377213
#
# Sold MAR at 2020-11-06 for a profit of 116.927982 returning 1376.508002 as revenue
# New budget:  10299.915649377213
#
# Bought  NWS  at  2020-11-06 for 81 n shares with per share price: 15.140000, totaling: 1226.340028
# New budget is:  9073.575621451948
#
# Sold KLAC at 2020-11-09 for a profit of 109.332036 returning 1321.0320159999999 as revenue
# New budget:  10394.607637451947
#
# Sold CTAS at 2020-11-09 for a profit of 86.255964 returning 1032.875994 as revenue
# New budget:  11427.483631451947
#
# Sold HST at 2020-11-09 for a profit of 191.868000 returning 1481.60804 as revenue
# New budget:  12909.091671451948
#
# Bought  NWSA  at  2020-11-09 for 98 n shares with per share price: 15.670000, totaling: 1535.660007
# New budget is:  11373.431660877715
#
# Bought  ULTA  at  2020-11-09 for 5 n shares with per share price: 247.199997, totaling: 1235.999985
# New budget is:  10137.431671572389
#
# Bought  TSLA  at  2020-11-09 for 2 n shares with per share price: 421.260010, totaling: 842.520020
# New budget is:  9294.911650983702
#
# Sold TRMB at 2020-11-10 for a profit of 127.451970 returning 1429.53202 as revenue
# New budget:  10724.443670983703
#
# Bought  DISCK  at  2020-11-10 for 62 n shares with per share price: 20.730000, totaling: 1285.259972
# New budget is:  9439.183700465657
#
# Sold MRNA at 2020-11-11 for a profit of 131.519988 returning 1561.120058 as revenue
# New budget:  11000.303758465658
#
# Bought  MU  at  2020-11-11 for 23 n shares with per share price: 56.360001, totaling: 1296.280014
# New budget is:  9704.023747449779
#
# Sold TMUS at 2020-11-12 for a profit of 112.265964 returning 1320.0659939999998 as revenue
# New budget:  11024.08974144978
#
# Bought  HST  at  2020-11-12 for 108 n shares with per share price: 12.210000, totaling: 1318.680004
# New budget is:  9705.409732475806
#
# Sold DISCK at 2020-11-12 for a profit of -64.479940 returning 1220.78003 as revenue
# New budget:  10926.189762475806
#
# Bought  FANG  at  2020-11-12 for 41 n shares with per share price: 31.660000, totaling: 1298.059994
# New budget is:  9628.12977097871
#
# Sold APA at 2020-11-13 for a profit of 138.509940 returning 1672.37999 as revenue
# New budget:  11300.50976097871
#
# Bought  DISH  at  2020-11-13 for 42 n shares with per share price: 31.540001, totaling: 1324.680038
# New budget is:  9975.829719661264
#
# Sold NWS at 2020-11-16 for a profit of 119.556000 returning 1345.89603 as revenue
# New budget:  11321.725749661264
#
# Sold WBA at 2020-11-16 for a profit of 130.367946 returning 1324.287986 as revenue
# New budget:  12646.013735661263
#
# Bought  MRNA  at  2020-11-16 for 15 n shares with per share price: 97.949997, totaling: 1469.249954
# New budget is:  11176.763777381911
#
# Bought  STX  at  2020-11-17 for 24 n shares with per share price: 55.509998, totaling: 1332.239960
# New budget is:  9844.523814096083
#
# Sold FANG at 2020-11-17 for a profit of 138.990042 returning 1437.050032 as revenue
# New budget:  11281.573846096082
#
# Sold HST at 2020-11-17 for a profit of 125.064024 returning 1443.744024 as revenue
# New budget:  12725.317870096082
#
# Sold TSLA at 2020-11-18 for a profit of 78.456006 returning 920.976026 as revenue
# New budget:  13646.293896096082
#
# Bought  FANG  at  2020-11-18 for 43 n shares with per share price: 37.740002, totaling: 1622.820072
# New budget is:  12023.47382856455
#
# Bought  INTC  at  2020-11-18 for 32 n shares with per share price: 45.060001, totaling: 1441.920044
# New budget is:  10581.553789136804
#
# Bought  ALGN  at  2020-11-18 for 2 n shares with per share price: 444.609985, totaling: 889.219971
# New budget is:  9692.333814440388
#
# Sold MRNA at 2020-11-18 for a profit of -135.899960 returning 1333.34999 as revenue
# New budget:  11025.683804440388
#
# Bought  UAL  at  2020-11-18 for 32 n shares with per share price: 41.049999, totaling: 1313.599976
# New budget is:  9712.083827907541
#
# Sold DISCA at 2020-11-19 for a profit of 149.040018 returning 1627.710038 as revenue
# New budget:  11339.79386590754
#
# Bought  APA  at  2020-11-19 for 119 n shares with per share price: 11.350000, totaling: 1350.650045
# New budget is:  9989.143821998636
#
# Sold CZR at 2020-11-19 for a profit of 149.760036 returning 1609.140066 as revenue
# New budget:  11598.283887998636
#
# Bought  CZR  at  2020-11-20 for 21 n shares with per share price: 64.010002, totaling: 1344.210045
# New budget is:  10254.0738414388
#
# Bought  WYNN  at  2020-11-20 for 12 n shares with per share price: 95.290001, totaling: 1143.480011
# New budget is:  9110.593830466145
#
# Sold PFG at 2020-11-23 for a profit of 187.698024 returning 1951.107954 as revenue
# New budget:  11061.701784466146
#
# Sold FANG at 2020-11-23 for a profit of 174.150000 returning 1796.97007 as revenue
# New budget:  12858.671854466145
#
# Sold AAL at 2020-11-23 for a profit of 171.696000 returning 1865.29606 as revenue
# New budget:  14723.967914466146
#
# Sold AMAT at 2020-11-23 for a profit of 151.920042 returning 1830.7199719999999 as revenue
# New budget:  16554.687886466145
#
# Sold NWSA at 2020-11-24 for a profit of 147.000000 returning 1682.66001 as revenue
# New budget:  18237.347896466144
#
# Sold ULTA at 2020-11-24 for a profit of 112.529988 returning 1348.529968 as revenue
# New budget:  19585.877864466143
#
# Bought  MRNA  at  2020-11-24 for 23 n shares with per share price: 98.559998, totaling: 2266.879944
# New budget is:  17318.997920730206
#
# Sold DLTR at 2020-11-24 for a profit of 136.500000 returning 1467.89998 as revenue
# New budget:  18786.897900730204
#
# Sold NTAP at 2020-11-24 for a profit of 212.790042 returning 2127.900002 as revenue
# New budget:  20914.797902730203
#
# Sold NTRS at 2020-11-24 for a profit of 192.359982 returning 1823.960022 as revenue
# New budget:  22738.757924730202
#
# Bought  TSLA  at  2020-11-24 for 4 n shares with per share price: 555.380005, totaling: 2221.520020
# New budget is:  20517.237903762576
#
# Sold DISH at 2020-11-24 for a profit of 123.227982 returning 1447.9080219999998 as revenue
# New budget:  21965.145925762576
#
# Sold SIVB at 2020-11-24 for a profit of 116.303982 returning 1369.783962 as revenue
# New budget:  23334.929887762577
#
# Sold APA at 2020-11-24 for a profit of 192.065970 returning 1542.71602 as revenue
# New budget:  24877.645907762577
#
# Bought  EA  at  2020-11-25 for 24 n shares with per share price: 121.510002, totaling: 2916.240051
# New budget is:  21961.40585883107
#
# Bought  APA  at  2020-11-25 for 186 n shares with per share price: 14.120000, totaling: 2626.319979
# New budget is:  19335.08587577134
#
# Bought  ENPH  at  2020-11-25 for 16 n shares with per share price: 139.070007, totaling: 2225.120117
# New budget is:  17109.965760678777
#
# Bought  ILMN  at  2020-11-25 for 6 n shares with per share price: 303.980011, totaling: 1823.880066
# New budget is:  15286.085699397323
# Bought  WDC  at  2020-11-25 for 40 n shares with per share price: 45.259998, totaling: 1810.399933
# New budget is:  13475.685765469645
#
# Bought  AAL  at  2020-11-27 for 107 n shares with per share price: 14.980000, totaling: 1602.859951
# New budget is:  11872.825813613288
#
# Bought  NTAP  at  2020-11-27 for 26 n shares with per share price: 53.259998, totaling: 1384.759956
# New budget is:  10488.065855979694
#
# Bought  FANG  at  2020-11-27 for 28 n shares with per share price: 43.520000, totaling: 1218.560013
# New budget is:  9269.505843262132
#
# Sold MRNA at 2020-11-27 for a profit of 392.886018 returning 2659.765958 as revenue
# New budget:  11929.271801262132
#
# Sold FANG at 2020-11-30 for a profit of -99.680040 returning 1118.87997 as revenue
# New budget:  13048.151771262132
#
# Bought  PENN  at  2020-11-30 for 22 n shares with per share price: 70.000000, totaling: 1540.000000
# New budget is:  11508.151768710677
#
# Sold AAL at 2020-11-30 for a profit of -90.949940 returning 1511.91001 as revenue
# New budget:  13020.061778710677
#
# Bought  ETSY  at  2020-11-30 for 9 n shares with per share price: 160.699997, totaling: 1446.299973
# New budget is:  11573.761805265396
#
# Sold APA at 2020-11-30 for a profit of -228.779920 returning 2397.54006 as revenue
# New budget:  13971.301865265395
#
# Sold ENPH at 2020-12-01 for a profit of -163.520020 returning 2061.6001 as revenue
# New budget:  16032.901965265395
#
# Bought  MRNA  at  2020-12-01 for 13 n shares with per share price: 141.009995, totaling: 1833.129929
# New budget is:  14199.772039433548
#
# Bought  AAL  at  2020-12-01 for 119 n shares with per share price: 14.270000, totaling: 1698.130054
# New budget is:  12501.641984701522
#
# Sold MU at 2020-12-01 for a profit of 147.936018 returning 1444.2160279999998 as revenue
# New budget:  13945.858012701523
#
# Bought  NLOK  at  2020-12-01 for 91 n shares with per share price: 18.230000, totaling: 1658.929958
# New budget is:  12286.928051177341
#
# Bought  APA  at  2020-12-01 for 119 n shares with per share price: 12.370000, totaling: 1472.029986
# New budget is:  10814.898065036059
#
# Bought  FTNT  at  2020-12-02 for 10 n shares with per share price: 122.879997, totaling: 1228.799973
# New budget is:  9586.098097231732
#
# Sold UAL at 2020-12-03 for a profit of 170.112012 returning 1483.711992 as revenue
# New budget:  11069.810089231732
#
# Sold APA at 2020-12-04 for a profit of 200.634030 returning 1672.66402 as revenue
# New budget:  12742.474109231733
#
# Sold STX at 2020-12-04 for a profit of 123.264018 returning 1455.5039780000002 as revenue
# New budget:  14197.978087231733
#
# Sold INTC at 2020-12-04 for a profit of 133.056006 returning 1574.976046 as revenue
# New budget:  15772.954133231733
#
# Sold WYNN at 2020-12-04 for a profit of 131.111994 returning 1274.592004 as revenue
# New budget:  17047.546137231733
#
# Sold ALGN at 2020-12-04 for a profit of 92.531982 returning 981.751952 as revenue
# New budget:  18029.298089231732
#
# Sold CZR at 2020-12-04 for a profit of 123.857928 returning 1468.067968 as revenue
# New budget:  19497.36605723173
#
# Sold ILMN at 2020-12-04 for a profit of 168.047970 returning 1991.92804 as revenue
# New budget:  21489.29409723173
#
# Bought  ENPH  at  2020-12-07 for 19 n shares with per share price: 129.320007, totaling: 2457.080139
# New budget is:  19032.213955563922
#
# Sold AAL at 2020-12-07 for a profit of 209.915904 returning 1908.045954 as revenue
# New budget:  20940.259909563923
#
# Sold TSLA at 2020-12-07 for a profit of 207.312012 returning 2428.832032 as revenue
# New budget:  23369.091941563922
#
# Sold MRNA at 2020-12-08 for a profit of 225.030048 returning 2058.159978 as revenue
# New budget:  25427.25191956392
#
# Sold WDC at 2020-12-08 for a profit of 171.840000 returning 1982.23993 as revenue
# New budget:  27409.49184956392
#
# Bought  CDNS  at  2020-12-09 for 28 n shares with per share price: 115.489998, totaling: 3233.719940
# New budget is:  24175.77190761625
#
# Bought  MPWR  at  2020-12-09 for 9 n shares with per share price: 308.609985, totaling: 2777.489868
# New budget is:  21398.282038702302
#
# Bought  PYPL  at  2020-12-09 for 12 n shares with per share price: 210.800003, totaling: 2529.600037
# New budget is:  18868.682004058028
#
# Bought  ABMD  at  2020-12-09 for 8 n shares with per share price: 266.149994, totaling: 2129.199951
# New budget is:  16739.482053571064
#
# Bought  TSLA  at  2020-12-09 for 3 n shares with per share price: 604.479980, totaling: 1813.439941
# New budget is:  14926.042117142535
#
# Sold NTAP at 2020-12-11 for a profit of 133.536018 returning 1518.2959779999999 as revenue
# New budget:  16444.338095142535
#
# Bought  AAL  at  2020-12-14 for 118 n shares with per share price: 16.700001, totaling: 1970.600090
# New budget is:  14473.738003725432
#
# Sold PENN at 2020-12-15 for a profit of 172.787952 returning 1712.787952 as revenue
# New budget:  16186.525955725432
#
# Sold ENPH at 2020-12-15 for a profit of 354.995994 returning 2812.076134 as revenue
# New budget:  18998.60208972543
#
# Sold EA at 2020-12-15 for a profit of 275.760024 returning 3192.0000740000005 as revenue
# New budget:  22190.60216372543
#
# Bought  SIVB  at  2020-12-16 for 7 n shares with per share price: 358.339996, totaling: 2508.379974
# New budget is:  19682.22219407838
#
# Bought  ZION  at  2020-12-16 for 56 n shares with per share price: 41.869999, totaling: 2344.719940
# New budget is:  17337.502250788973
#
# Bought  DISCK  at  2020-12-16 for 82 n shares with per share price: 25.320000, totaling: 2076.239975
# New budget is:  15261.262280694296
#
# Bought  FITB  at  2020-12-17 for 67 n shares with per share price: 27.129999, totaling: 1817.709944
# New budget is:  13443.552337010982
#
# Bought  DISCA  at  2020-12-17 for 56 n shares with per share price: 28.740000, totaling: 1609.439987
# New budget is:  11834.112346569664
#
# Bought  HBAN  at  2020-12-17 for 115 n shares with per share price: 12.340000, totaling: 1419.100018
# New budget is:  10415.012324981304
#
# Sold ETSY at 2020-12-17 for a profit of 147.960048 returning 1594.260018 as revenue
# New budget:  12009.272342981305
#
# Sold NLOK at 2020-12-18 for a profit of 164.346012 returning 1823.275972 as revenue
# New budget:  13832.548314981304
#
# Sold FTNT at 2020-12-18 for a profit of 137.820054 returning 1366.620024 as revenue
# New budget:  15199.168338981304
#
# Bought  ENPH  at  2020-12-18 for 11 n shares with per share price: 164.410004, totaling: 1808.510040
# New budget is:  13390.65829830355
#
# Bought  APA  at  2020-12-21 for 108 n shares with per share price: 14.850000, totaling: 1603.800041
# New budget is:  11786.858252507123
#
# Bought  EXPE  at  2020-12-21 for 11 n shares with per share price: 123.360001, totaling: 1356.960007
# New budget is:  10429.898242206269
#
# Bought  WBA  at  2020-12-21 for 30 n shares with per share price: 40.669998, totaling: 1220.099945
# New budget is:  9209.798293141517
#
# Sold DISCK at 2020-12-21 for a profit of -106.599930 returning 1969.64004 as revenue
# New budget:  11179.438333141517
#
# Bought  VIAC  at  2020-12-21 for 38 n shares with per share price: 34.849998, totaling: 1324.299942
# New budget is:  9855.138393164534
#
# Sold AAL at 2020-12-22 for a profit of -143.960140 returning 1826.63995 as revenue
# New budget:  11681.778343164535
#
# Bought  FOXA  at  2020-12-22 for 51 n shares with per share price: 27.270000, totaling: 1390.770023
# New budget is:  10291.00832198479
#
# Bought  FOX  at  2020-12-22 for 45 n shares with per share price: 26.980000, totaling: 1214.099979
# New budget is:  9076.908343346615
#
# Sold DISCA at 2020-12-22 for a profit of -85.680040 returning 1523.75995 as revenue
# New budget:  10600.668293346615
#
# Bought  TER  at  2020-12-22 for 10 n shares with per share price: 118.570000, totaling: 1185.699997
# New budget is:  9414.96829814502
#
# Sold CDNS at 2020-12-22 for a profit of 317.183952 returning 3550.903892 as revenue
# New budget:  12965.87219014502
#
# Sold PYPL at 2020-12-22 for a profit of 235.368018 returning 2764.9680580000004 as revenue
# New budget:  15730.840248145021
#
# Bought  DISCK  at  2020-12-22 for 79 n shares with per share price: 23.860001, totaling: 1884.940048
# New budget is:  13845.900198367619
#
# Bought  INTC  at  2020-12-22 for 35 n shares with per share price: 46.169998, totaling: 1615.949936
# New budget is:  12229.950264563506
#
# Bought  XRAY  at  2020-12-22 for 28 n shares with per share price: 51.810001, totaling: 1450.680038
# New budget is:  10779.270222815883
# Bought  MRNA  at  2020-12-23 for 9 n shares with per share price: 130.339996, totaling: 1173.059967
# New budget is:  9606.210256077979
#
# Sold MRNA at 2020-12-24 for a profit of -62.549980 returning 1110.50999 as revenue
# New budget:  10716.720246077979
#
# Sold MPWR at 2020-12-24 for a profit of 261.684120 returning 3039.1739900000002 as revenue
# New budget:  13755.89423607798
#
# Bought  KLAC  at  2020-12-24 for 6 n shares with per share price: 259.079987, totaling: 1554.479919
# New budget is:  12201.414317748622
#
# Bought  LRCX  at  2020-12-24 for 3 n shares with per share price: 480.339996, totaling: 1441.019989
# New budget is:  10760.394329618786
#
# Bought  DISCA  at  2020-12-24 for 45 n shares with per share price: 28.570000, totaling: 1285.649986
# New budget is:  9474.744340064532
#
# Sold ABMD at 2020-12-28 for a profit of 224.448048 returning 2353.647998 as revenue
# New budget:  11828.392338064532
#
# Bought  AMAT  at  2020-12-28 for 16 n shares with per share price: 84.870003, totaling: 1357.920044
# New budget is:  10470.472297496788
#
# Bought  MRNA  at  2020-12-28 for 11 n shares with per share price: 111.400002, totaling: 1225.400017
# New budget is:  9245.072281797175
#
# Sold MRNA at 2020-12-31 for a profit of -76.230010 returning 1149.17001 as revenue
# New budget:  10394.242291797174
#
# Bought  IPGP  at  2020-12-31 for 5 n shares with per share price: 223.789993, totaling: 1118.949966
# New budget is:  9275.292326781513
#
# Sold TSLA at 2020-12-31 for a profit of 182.142006 returning 1995.5819460000002 as revenue
# New budget:  11270.874272781513
#
# Bought  BIIB  at  2021-01-04 for 5 n shares with per share price: 242.949997, totaling: 1214.749985
# New budget is:  10056.12429004773
#
# Bought  PENN  at  2021-01-04 for 14 n shares with per share price: 80.889999, totaling: 1132.459991
# New budget is:  8923.664295242002
#
# Sold DISCK at 2021-01-06 for a profit of 267.335970 returning 2152.27602 as revenue
# New budget:  11075.940315242002
#
# Sold FOX at 2021-01-06 for a profit of 120.959988 returning 1335.059968 as revenue
# New budget:  12411.000283242001
#
# Sold ENPH at 2021-01-06 for a profit of 257.202006 returning 2065.7120459999996 as revenue
# New budget:  14476.712329242
#
# Sold FOXA at 2021-01-06 for a profit of 145.043934 returning 1535.813954 as revenue
# New budget:  16012.526283242
#
# Bought  ETSY  at  2021-01-06 for 11 n shares with per share price: 167.570007, totaling: 1843.270081
# New budget is:  14169.256199252959
#
# Sold ZION at 2021-01-06 for a profit of 223.103982 returning 2567.823922 as revenue
# New budget:  16737.08012125296
#
# Bought  AKAM  at  2021-01-06 for 19 n shares with per share price: 101.529999, totaling: 1929.069977
# New budget is:  14808.010146702603
#
# Sold EXPE at 2021-01-06 for a profit of 132.395982 returning 1489.355992 as revenue
# New budget:  16297.366138702604
#
# Bought  REGN  at  2021-01-06 for 4 n shares with per share price: 470.089996, totaling: 1880.359985
# New budget is:  14417.006152058291
#
# Sold VIAC at 2021-01-06 for a profit of 121.980054 returning 1446.279994 as revenue
# New budget:  15863.286146058292
#
# Sold DISCA at 2021-01-06 for a profit of 153.360006 returning 1439.0099959999998 as revenue
# New budget:  17302.29614205829
#
# Bought  NFLX  at  2021-01-06 for 4 n shares with per share price: 500.489990, totaling: 2001.959961
# New budget is:  15300.336185011296
#
# Sold SIVB at 2021-01-06 for a profit of 240.114060 returning 2748.4940300000003 as revenue
# New budget:  18048.830215011298
#
# Sold FITB at 2021-01-07 for a profit of 173.262060 returning 1990.972 as revenue
# New budget:  20039.8022150113
#
# Bought  STX  at  2021-01-07 for 40 n shares with per share price: 60.110001, totaling: 2404.400024
# New budget is:  17635.402189209944
#
# Bought  MRNA  at  2021-01-07 for 18 n shares with per share price: 115.089996, totaling: 2071.619934
# New budget is:  15563.78225650475
#
# Bought  VIAC  at  2021-01-07 for 46 n shares with per share price: 40.119999, totaling: 1845.519951
# New budget is:  13718.26230572418
#
# Bought  FFIV  at  2021-01-07 for 9 n shares with per share price: 180.100006, totaling: 1620.900055
# New budget is:  12097.362249037278
#
# Bought  DISCA  at  2021-01-07 for 42 n shares with per share price: 34.400002, totaling: 1444.800064
# New budget is:  10652.562189152804
#
# Sold APA at 2021-01-07 for a profit of 146.448018 returning 1750.248058 as revenue
# New budget:  12402.810247152804
#
# Sold HBAN at 2021-01-07 for a profit of 144.899958 returning 1563.999978 as revenue
# New budget:  13966.810225152803
#
# Bought  ILMN  at  2021-01-08 for 4 n shares with per share price: 379.609985, totaling: 1518.439941
# New budget is:  12448.370288134467
#
# Bought  AAL  at  2021-01-08 for 98 n shares with per share price: 15.130000, totaling: 1482.740011
# New budget is:  10965.630273558332
#
# Sold PENN at 2021-01-08 for a profit of 108.024006 returning 1240.4839960000002 as revenue
# New budget:  12206.114269558333
#
# Sold WBA at 2021-01-11 for a profit of 126.540042 returning 1346.6399920000001 as revenue
# New budget:  13552.754261558333
#
# Bought  DISCK  at  2021-01-11 for 53 n shares with per share price: 30.590000, totaling: 1621.270008
# New budget is:  11931.484250171334
#
# Sold AMAT at 2021-01-11 for a profit of 125.663970 returning 1483.58401 as revenue
# New budget:  13415.068260171334
#
# Bought  FOXA  at  2021-01-11 for 53 n shares with per share price: 30.330000, totaling: 1607.489996
# New budget is:  11807.578268950774
#
# Sold XRAY at 2021-01-12 for a profit of 136.751988 returning 1587.4320280000002 as revenue
# New budget:  13395.010296950775
#
# Sold INTC at 2021-01-12 for a profit of 148.470072 returning 1764.420012 as revenue
# New budget:  15159.430308950776
#
# Sold TER at 2021-01-12 for a profit of 111.119976 returning 1296.819976 as revenue
# New budget:  16456.250284950776
#
# Bought  SWKS  at  2021-01-12 for 12 n shares with per share price: 158.179993, totaling: 1898.159912
# New budget is:  14558.090370756683
#
# Sold ETSY at 2021-01-12 for a profit of 248.027910 returning 2091.29799 as revenue
# New budget:  16649.388360756682
#
# Bought  WDC  at  2021-01-13 for 40 n shares with per share price: 49.470001, totaling: 1978.800049
# New budget is:  14670.588307465881
#
# Sold KLAC at 2021-01-14 for a profit of 161.280066 returning 1715.7599859999998 as revenue
# New budget:  16386.348293465882
#
# Bought  GOOG  at  2021-01-14 for 1 n shares with per share price: 1740.180054, totaling: 1740.180054
# New budget is:  14646.168238249977
#
# Sold BIIB at 2021-01-14 for a profit of 112.020036 returning 1326.770016 as revenue
# New budget:  15972.938254249977
#
# Sold LRCX at 2021-01-14 for a profit of 139.409964 returning 1580.429954 as revenue
# New budget:  17553.368208249976
#
# Bought  PENN  at  2021-01-15 for 21 n shares with per share price: 99.110001, totaling: 2081.310013
# New budget is:  15472.05819325998
#
# Sold IPGP at 2021-01-19 for a profit of 104.369976 returning 1223.319946 as revenue
# New budget:  16695.37813925998
#
# Bought  GOOGL  at  2021-01-19 for 1 n shares with per share price: 1784.469971, totaling: 1784.469971
# New budget is:  14910.908172548785
#
# Sold NFLX at 2021-01-20 for a profit of 206.040090 returning 2208.00005 as revenue
# New budget:  17118.908222548784
#
# Bought  PYPL  at  2021-01-20 for 8 n shares with per share price: 244.259995, totaling: 1954.079956
# New budget is:  15164.828265842929
#
# Sold REGN at 2021-01-20 for a profit of 173.232054 returning 2053.592044 as revenue
# New budget:  17218.420309842928
#
# Bought  NWS  at  2021-01-21 for 110 n shares with per share price: 18.740000, totaling: 2061.399975
# New budget is:  15157.020332661778
#
# Bought  NWSA  at  2021-01-21 for 94 n shares with per share price: 19.209999, totaling: 1805.739914
# New budget is:  13351.280422742364
#
# Sold MRNA at 2021-01-21 for a profit of 193.211994 returning 2264.831924 as revenue
# New budget:  15616.112346742364
#
# Bought  ALGN  at  2021-01-22 for 3 n shares with per share price: 534.080017, totaling: 1602.240051
# New budget is:  14013.87229513328
#
# Bought  CDW  at  2021-01-22 for 12 n shares with per share price: 135.320007, totaling: 1623.840088
# New budget is:  12390.032209717287
#
# Bought  MTCH  at  2021-01-22 for 10 n shares with per share price: 141.000000, totaling: 1410.000000
# New budget is:  10980.032214551213
#
# Bought  MRNA  at  2021-01-22 for 10 n shares with per share price: 131.020004, totaling: 1310.200043
# New budget is:  9669.832168805067
# Sold FFIV at 2021-01-25 for a profit of 146.609970 returning 1767.51002 as revenue
# New budget:  11437.342188805067
#
# Sold VIAC at 2021-01-25 for a profit of 209.484006 returning 2055.003956 as revenue
# New budget:  13492.346144805068
#
# Sold DISCA at 2021-01-26 for a profit of 159.263994 returning 1604.064054 as revenue
# New budget:  15096.410198805068
#
# Sold MRNA at 2021-01-26 for a profit of 125.459934 returning 1435.659974 as revenue
# New budget:  16532.070172805066
#
# Bought  FANG  at  2021-01-26 for 33 n shares with per share price: 59.610001, totaling: 1967.130020
# New budget is:  14564.940152068459
#
# Sold DISCK at 2021-01-26 for a profit of 152.958042 returning 1774.2280520000002 as revenue
# New budget:  16339.168204068459
#
# Bought  ZBRA  at  2021-01-26 for 4 n shares with per share price: 395.160004, totaling: 1580.640015
# New budget is:  14758.528189580245
#
# Bought  APA  at  2021-01-26 for 115 n shares with per share price: 15.300000, totaling: 1759.500022
# New budget is:  12999.028166830616
#
# Sold FOXA at 2021-01-26 for a profit of 146.280012 returning 1753.770012 as revenue
# New budget:  14752.798178830617
#
# Sold AKAM at 2021-01-26 for a profit of 176.358012 returning 2105.427992 as revenue
# New budget:  16858.226170830618
#
# Bought  TECH  at  2021-01-26 for 5 n shares with per share price: 340.339996, totaling: 1701.699982
# New budget is:  15156.526190330944
#
# Bought  MCHP  at  2021-01-27 for 13 n shares with per share price: 133.039993, totaling: 1729.519913
# New budget is:  13427.006277491231
#
# Sold FANG at 2021-01-27 for a profit of -99.660010 returning 1867.47001 as revenue
# New budget:  15294.47628749123
#
# Bought  NVDA  at  2021-01-27 for 3 n shares with per share price: 516.710022, totaling: 1550.130066
# New budget is:  13744.346222992282
#
# Sold TECH at 2021-01-27 for a profit of -109.550020 returning 1592.14996 as revenue
# New budget:  15336.496182992283
#
# Bought  SIVB  at  2021-01-27 for 4 n shares with per share price: 448.100006, totaling: 1792.400024
# New budget is:  13544.09616103321
#
# Bought  AMAT  at  2021-01-27 for 16 n shares with per share price: 98.580002, totaling: 1577.280029
# New budget is:  11966.816131709225
#
# Bought  WYNN  at  2021-01-27 for 14 n shares with per share price: 100.800003, totaling: 1411.200043
# New budget is:  10555.61608590412
#
# Bought  ENPH  at  2021-01-27 for 7 n shares with per share price: 179.020004, totaling: 1253.140030
# New budget is:  9302.476055595625
#
# Sold MTCH at 2021-01-27 for a profit of -94.499970 returning 1315.50003 as revenue
# New budget:  10617.976085595625
#
# Sold PYPL at 2021-01-27 for a profit of -114.559940 returning 1839.52002 as revenue
# New budget:  12457.496105595625
#
# Bought  DISCK  at  2021-01-27 for 44 n shares with per share price: 33.470001, totaling: 1472.680054
# New budget is:  10984.81605292415
#
# Bought  CZR  at  2021-01-27 for 19 n shares with per share price: 66.870003, totaling: 1270.530052
# New budget is:  9714.285996573253
#
# Sold STX at 2021-01-27 for a profit of 278.640018 returning 2683.040038 as revenue
# New budget:  12397.326034573252
#
# Sold ILMN at 2021-01-28 for a profit of 140.664036 returning 1659.103976 as revenue
# New budget:  14056.430010573253
#
# Bought  DISCA  at  2021-01-28 for 41 n shares with per share price: 41.020000, totaling: 1681.820019
# New budget is:  12374.609989304463
#
# Bought  ETSY  at  2021-01-28 for 7 n shares with per share price: 202.410004, totaling: 1416.870026
# New budget is:  10957.739960587927
#
# Bought  VIAC  at  2021-01-28 for 25 n shares with per share price: 50.610001, totaling: 1265.250015
# New budget is:  9692.489945317377
#
# Sold AAL at 2021-01-28 for a profit of 174.636018 returning 1657.376028 as revenue
# New budget:  11349.865973317377
#
# Bought  NXPI  at  2021-01-28 for 8 n shares with per share price: 164.330002, totaling: 1314.640015
# New budget is:  10035.225956519293
#
# Bought  MRNA  at  2021-01-28 for 7 n shares with per share price: 159.550003, totaling: 1116.850021
# New budget is:  8918.375931736977
#
# Sold APA at 2021-01-29 for a profit of -117.300050 returning 1642.19997 as revenue
# New budget:  10560.575901736976
#
# Bought  TER  at  2021-01-29 for 11 n shares with per share price: 113.480003, totaling: 1248.280037
# New budget is:  9312.29586352854
#
# Sold WDC at 2021-02-01 for a profit of 194.879976 returning 2173.680026 as revenue
# New budget:  11485.97588952854
#
# Bought  FITB  at  2021-02-01 for 46 n shares with per share price: 29.490000, totaling: 1356.539989
# New budget is:  10129.435902785115
#
# Bought  KLAC  at  2021-02-01 for 4 n shares with per share price: 292.619995, totaling: 1170.479980
# New budget is:  8958.955924450902
#
# Sold SWKS at 2021-02-01 for a profit of 198.792006 returning 2096.9519160000004 as revenue
# New budget:  11055.907840450902
#
# Bought  KHC  at  2021-02-01 for 39 n shares with per share price: 33.250000, totaling: 1296.750000
# New budget is:  9759.157839596794
#
# Sold GOOG at 2021-02-03 for a profit of 197.934012 returning 1938.114062 as revenue
# New budget:  11697.271901596794
#
# Sold GOOGL at 2021-02-03 for a profit of 164.645946 returning 1949.115916 as revenue
# New budget:  13646.387817596795
#
# Bought  HBAN  at  2021-02-03 for 120 n shares with per share price: 13.620000, totaling: 1634.399986
# New budget is:  12011.987829485179
#
# Bought  ZION  at  2021-02-04 for 29 n shares with per share price: 48.220001, totaling: 1398.380035
# New budget is:  10613.607789946956
#
# Sold ALGN at 2021-02-04 for a profit of 145.943922 returning 1748.1839719999998 as revenue
# New budget:  12361.791761946955
#
# Bought  TSCO  at  2021-02-04 for 10 n shares with per share price: 146.240005, totaling: 1462.400055
# New budget is:  10899.39171051332
#
# Sold CZR at 2021-02-04 for a profit of 143.754006 returning 1414.284056 as revenue
# New budget:  12313.675766513321
#
# Bought  AAL  at  2021-02-04 for 84 n shares with per share price: 17.400000, totaling: 1461.599968
# New budget is:  10852.075794531722
#
# Bought  APA  at  2021-02-04 for 79 n shares with per share price: 16.320000, totaling: 1289.279976
# New budget is:  9562.795819187915
#
# Sold PENN at 2021-02-04 for a profit of 242.297946 returning 2323.6079560000003 as revenue
# New budget:  11886.403775187915
#
# Bought  BKNG  at  2021-02-05 for 0 n shares with per share price: 2096.419922, totaling: 0.000000
# New budget is:  11886.403772165366
#
# Bought  HST  at  2021-02-05 for 100 n shares with per share price: 14.200000, totaling: 1419.999981
# New budget is:  10466.40378950552
#
# Bought  ILMN  at  2021-02-05 for 2 n shares with per share price: 428.910004, totaling: 857.820007
# New budget is:  9608.583784764858
#
# Sold WYNN at 2021-02-05 for a profit of 135.995958 returning 1547.195998 as revenue
# New budget:  11155.779782764857
#
# Bought  CINF  at  2021-02-05 for 15 n shares with per share price: 86.709999, totaling: 1300.649986
# New budget is:  9855.129798833073
#
# Sold MRNA at 2021-02-08 for a profit of 111.005970 returning 1227.8559899999998 as revenue
# New budget:  11082.985788833073
#
# Bought  UAL  at  2021-02-08 for 29 n shares with per share price: 44.349998, totaling: 1286.149956
# New budget is:  9796.835834173104
#
# Sold NWS at 2021-02-09 for a profit of 213.179970 returning 2274.57994 as revenue
# New budget:  12071.415774173103
#
# Bought  PBCT  at  2021-02-09 for 96 n shares with per share price: 15.030000, totaling: 1442.879974
# New budget is:  10628.535801272332
#
# Sold NWSA at 2021-02-09 for a profit of 167.508072 returning 1973.2479820000003 as revenue
# New budget:  12601.783783272333
#
# Bought  CZR  at  2021-02-09 for 18 n shares with per share price: 81.570000, totaling: 1468.259995
# New budget is:  11133.523789279652
#
# Bought  WDC  at  2021-02-10 for 22 n shares with per share price: 60.389999, totaling: 1328.579987
# New budget is:  9804.943804566095
#
# Sold CDW at 2021-02-10 for a profit of 158.543922 returning 1782.3840120000002 as revenue
# New budget:  11587.327816566096
#
# Bought  MU  at  2021-02-10 for 16 n shares with per share price: 82.349998, totaling: 1317.599976
# New budget is:  10269.727838578165
#
# Bought  FOXA  at  2021-02-10 for 38 n shares with per share price: 31.780001, totaling: 1207.640026
# New budget is:  9062.087807948785
#
# Sold ZBRA at 2021-02-11 for a profit of 179.807964 returning 1760.4479740000002 as revenue
# New budget:  10822.535781948785
#
# Sold TER at 2021-02-11 for a profit of 142.295934 returning 1390.575974 as revenue
# New budget:  12213.111755948785
#
# Sold DISCK at 2021-02-11 for a profit of 145.991970 returning 1618.67202 as revenue
# New budget:  13831.783775948785
#
# Sold MCHP at 2021-02-11 for a profit of 191.802090 returning 1921.322 as revenue
# New budget:  15753.105775948785
#
# Sold NXPI at 2021-02-11 for a profit of 142.415994 returning 1457.056004 as revenue
# New budget:  17210.161779948787
# Sold NVDA at 2021-02-11 for a profit of 167.976012 returning 1718.106082 as revenue
# New budget:  18928.267861948785
#
# Sold DISCA at 2021-02-12 for a profit of 166.787970 returning 1848.60799 as revenue
# New budget:  20776.875851948786
#
# Bought  FOX  at  2021-02-12 for 79 n shares with per share price: 31.450001, totaling: 2484.550060
# New budget is:  18292.32578971493
#
# Sold AMAT at 2021-02-12 for a profit of 173.951952 returning 1751.2319819999998 as revenue
# New budget:  20043.55777171493
#
# Sold VIAC at 2021-02-12 for a profit of 115.500006 returning 1380.750026 as revenue
# New budget:  21424.307797714933
#
# Sold ILMN at 2021-02-12 for a profit of 91.020006 returning 948.840016 as revenue
# New budget:  22373.14781371493
#
# Sold ENPH at 2021-02-12 for a profit of 115.457958 returning 1368.597988 as revenue
# New budget:  23741.745801714933
#
# Sold ETSY at 2021-02-12 for a profit of 132.089982 returning 1548.960012 as revenue
# New budget:  25290.705813714932
#
# Bought  MAR  at  2021-02-12 for 23 n shares with per share price: 129.479996, totaling: 2978.039902
# New budget is:  22312.66591606914
#
# Bought  DISCA  at  2021-02-16 for 56 n shares with per share price: 47.349998, totaling: 2651.599915
# New budget is:  19661.06600614084
#
# Sold SIVB at 2021-02-16 for a profit of 184.920048 returning 1977.320068 as revenue
# New budget:  21638.386074140843
#
# Sold KLAC at 2021-02-16 for a profit of 106.943994 returning 1277.423974 as revenue
# New budget:  22915.810048140844
#
# Bought  VIAC  at  2021-02-16 for 46 n shares with per share price: 59.139999, totaling: 2720.439972
# New budget is:  20195.37007236394
#
# Bought  DISCK  at  2021-02-16 for 59 n shares with per share price: 40.500000, totaling: 2389.500000
# New budget is:  17805.870073680268
#
# Bought  FANG  at  2021-02-17 for 31 n shares with per share price: 68.839996, totaling: 2134.039886
# New budget is:  15671.830184838636
#
# Sold TSCO at 2021-02-17 for a profit of 144.059970 returning 1606.46002 as revenue
# New budget:  17278.290204838635
#
# Sold FANG at 2021-02-18 for a profit of -114.699910 returning 2019.33998 as revenue
# New budget:  19297.630184838636
#
# Sold KHC at 2021-02-18 for a profit of 133.613976 returning 1430.363976 as revenue
# New budget:  20727.994160838636
#
# Sold FITB at 2021-02-19 for a profit of 139.380030 returning 1495.92002 as revenue
# New budget:  22223.914180838638
#
# Sold HST at 2021-02-19 for a profit of 152.400000 returning 1572.3999800000001 as revenue
# New budget:  23796.314160838636
#
# Sold APA at 2021-02-22 for a profit of 130.824006 returning 1420.103986 as revenue
# New budget:  25216.418146838638
#
# Sold DISCA at 2021-02-22 for a profit of 266.784084 returning 2918.383994 as revenue
# New budget:  28134.802140838638
#
# Sold AAL at 2021-02-22 for a profit of 153.216042 returning 1614.816012 as revenue
# New budget:  29749.618152838637
#
# Sold PBCT at 2021-02-22 for a profit of 172.224042 returning 1615.104012 as revenue
# New budget:  31364.722164838637
#
# Sold MAR at 2021-02-23 for a profit of 276.966102 returning 3255.006002 as revenue
# New budget:  34619.728166838635
#
# Bought  DISCA  at  2021-02-23 for 78 n shares with per share price: 52.950001, totaling: 4130.100060
# New budget is:  30489.628106817996
#
# Bought  APA  at  2021-02-23 for 185 n shares with per share price: 19.750000, totaling: 3653.750000
# New budget is:  26835.878103999836
#
# Bought  DISH  at  2021-02-23 for 104 n shares with per share price: 30.950001, totaling: 3218.800079
# New budget is:  23617.078021519857
#
# Bought  ETSY  at  2021-02-23 for 13 n shares with per share price: 210.750000, totaling: 2739.750000
# New budget is:  20877.328018937475
#
# Bought  XRAY  at  2021-02-23 for 46 n shares with per share price: 53.360001, totaling: 2454.560028
# New budget is:  18422.767986664978
#
# Sold HBAN at 2021-02-23 for a profit of 151.200024 returning 1785.6000139999999 as revenue
# New budget:  20208.368000664977
#
# Sold WDC at 2021-02-24 for a profit of 133.847988 returning 1462.427978 as revenue
# New budget:  21670.795978664977
#
# Sold ZION at 2021-02-24 for a profit of 148.943952 returning 1547.323992 as revenue
# New budget:  23218.11997066498
#
# Sold BKNG at 2021-02-24 for a profit of 0.000000 returning 0.0 as revenue
# New budget:  23218.11997066498
#
# Bought  AAL  at  2021-02-24 for 127 n shares with per share price: 21.820000, totaling: 2771.139961
# New budget is:  20446.98001418518
#
# Sold CINF at 2021-02-24 for a profit of 127.620000 returning 1428.2699899999998 as revenue
# New budget:  21875.25000418518
#
# Bought  FANG  at  2021-02-24 for 35 n shares with per share price: 73.800003, totaling: 2583.000107
# New budget is:  19292.24989368296
#
# Sold UAL at 2021-02-24 for a profit of 184.614006 returning 1470.763966 as revenue
# New budget:  20763.01385968296
#
# Sold FANG at 2021-02-25 for a profit of -165.900200 returning 2417.09991 as revenue
# New budget:  23180.11376968296
#
# Bought  PENN  at  2021-02-25 for 25 n shares with per share price: 109.690002, totaling: 2742.250061
# New budget is:  20437.863707321005
#
# Sold ETSY at 2021-02-25 for a profit of -171.209980 returning 2568.54002 as revenue
# New budget:  23006.403727321005
#
# Bought  UAL  at  2021-02-26 for 52 n shares with per share price: 52.680000, totaling: 2739.360016
# New budget is:  20267.043710042486
#
# Sold PENN at 2021-03-01 for a profit of 248.549994 returning 2990.8000540000003 as revenue
# New budget:  23257.843764042485
#
# Bought  NWL  at  2021-03-01 for 115 n shares with per share price: 24.120001, totaling: 2773.800097
# New budget is:  20484.043672357388
#
# Sold MU at 2021-03-01 for a profit of 119.136030 returning 1436.7360099999999 as revenue
# New budget:  21920.779682357388
#
# Sold DISCK at 2021-03-01 for a profit of 276.474048 returning 2665.974048 as revenue
# New budget:  24586.753730357388
#
# Bought  CMCSA  at  2021-03-01 for 54 n shares with per share price: 54.450001, totaling: 2940.300041
# New budget is:  21646.4536927145
#
# Sold CZR at 2021-03-01 for a profit of 134.891982 returning 1603.1519720000001 as revenue
# New budget:  23249.6056647145
#
# Bought  NWSA  at  2021-03-01 for 114 n shares with per share price: 24.360001, totaling: 2777.040070
# New budget is:  20472.565594948763
#
# Bought  FANG  at  2021-03-02 for 34 n shares with per share price: 71.010002, totaling: 2414.340073
# New budget is:  18058.225523554913
#
# Sold VIAC at 2021-03-02 for a profit of 264.408054 returning 2984.8480240000004 as revenue
# New budget:  21043.07354755491
#
# Sold FOXA at 2021-03-02 for a profit of 140.676000 returning 1348.31603 as revenue
# New budget:  22391.38957755491
#
# Bought  DISCK  at  2021-03-02 for 54 n shares with per share price: 49.049999, totaling: 2648.699959
# New budget is:  19742.68961824832
#
# Sold FOX at 2021-03-03 for a profit of 267.335970 returning 2751.88603 as revenue
# New budget:  22494.575648248323
#
# Bought  VIAC  at  2021-03-03 for 38 n shares with per share price: 70.910004, totaling: 2694.580139
# New budget is:  19799.995510458524
#
# Bought  WBA  at  2021-03-03 for 49 n shares with per share price: 47.630001, totaling: 2333.870052
# New budget is:  17466.125459203504
#
# Bought  PENN  at  2021-03-03 for 17 n shares with per share price: 117.730003, totaling: 2001.410057
# New budget is:  15464.715404099083
#
# Sold DISCA at 2021-03-03 for a profit of 397.800000 returning 4527.90006 as revenue
# New budget:  19992.615464099083
#
# Bought  ENPH  at  2021-03-04 for 16 n shares with per share price: 149.880005, totaling: 2398.080078
# New budget is:  17594.535388407196
#
# Sold PENN at 2021-03-04 for a profit of -150.280070 returning 1851.12999 as revenue
# New budget:  19445.665378407197
#
# Bought  TSLA  at  2021-03-05 for 3 n shares with per share price: 597.950012, totaling: 1793.850037
# New budget is:  17651.815342998332
#
# Sold FANG at 2021-03-05 for a profit of 290.903892 returning 2705.2439619999996 as revenue
# New budget:  20357.059304998333
#
# Sold APA at 2021-03-05 for a profit of 388.500000 returning 4042.25 as revenue
# New budget:  24399.309304998333
#
# Sold AAL at 2021-03-05 for a profit of -173.989860 returning 2597.1501 as revenue
# New budget:  26996.45940499833
#
# Sold ENPH at 2021-03-08 for a profit of -285.120120 returning 2112.95996 as revenue
# New budget:  29109.41936499833
#
# Sold VIAC at 2021-03-08 for a profit of 290.700000 returning 2985.28014 as revenue
# New budget:  32094.69950499833
#
# Bought  MRNA  at  2021-03-08 for 31 n shares with per share price: 123.470001, totaling: 3827.570038
# New budget is:  28267.12946439853
# Bought  PENN  at  2021-03-08 for 31 n shares with per share price: 109.279999, totaling: 3387.679962
# New budget is:  24879.449498670707
#
# Sold TSLA at 2021-03-08 for a profit of -104.850040 returning 1689.0 as revenue
# New budget:  26568.449498670707
#
# Bought  AAL  at  2021-03-08 for 148 n shares with per share price: 21.469999, totaling: 3177.559898
# New budget is:  23390.889598830225
#
# Bought  NXPI  at  2021-03-08 for 16 n shares with per share price: 171.000000, totaling: 2736.000000
# New budget is:  20654.889596970595
#
# Sold XRAY at 2021-03-08 for a profit of 235.704024 returning 2690.264054 as revenue
# New budget:  23345.153650970595
#
# Bought  PTC  at  2021-03-08 for 23 n shares with per share price: 118.849998, totaling: 2733.549965
# New budget is:  20611.603682854126
#
# Bought  APA  at  2021-03-09 for 114 n shares with per share price: 21.600000, totaling: 2462.400043
# New budget is:  18149.20364091163
#
# Bought  ENPH  at  2021-03-09 for 14 n shares with per share price: 148.699997, totaling: 2081.799957
# New budget is:  16067.403684002235
#
# Bought  TSLA  at  2021-03-10 for 2 n shares with per share price: 668.059998, totaling: 1336.119995
# New budget is:  14731.283691921966
#
# Sold DISH at 2021-03-10 for a profit of 301.391874 returning 3520.191954 as revenue
# New budget:  18251.475645921964
#
# Bought  XRAY  at  2021-03-10 for 35 n shares with per share price: 62.060001, totaling: 2172.100048
# New budget is:  16079.375598411329
#
# Sold PENN at 2021-03-11 for a profit of 403.434048 returning 3791.114008 as revenue
# New budget:  19870.489606411327
#
# Sold DISCK at 2021-03-11 for a profit of 253.044042 returning 2901.7440020000004 as revenue
# New budget:  22772.233608411327
#
# Sold UAL at 2021-03-15 for a profit of 257.711946 returning 2997.071966 as revenue
# New budget:  25769.305574411326
#
# Sold MRNA at 2021-03-15 for a profit of 375.534042 returning 4203.104082 as revenue
# New budget:  29972.409656411328
#
# Sold WBA at 2021-03-15 for a profit of 218.147946 returning 2552.017996 as revenue
# New budget:  32524.427652411327
#
# Sold NXPI at 2021-03-15 for a profit of 277.536036 returning 3013.536036 as revenue
# New budget:  35537.96368841133
#
# Bought  DISH  at  2021-03-15 for 109 n shares with per share price: 38.779999, totaling: 4227.019867
# New budget is:  31310.943825801965
#
# Sold ENPH at 2021-03-15 for a profit of 213.864054 returning 2295.664014 as revenue
# New budget:  33606.60783980197
#
# Sold AAL at 2021-03-15 for a profit of 328.560066 returning 3506.119966 as revenue
# New budget:  37112.727805801966
#
# Sold PTC at 2021-03-15 for a profit of 251.711976 returning 2985.261936 as revenue
# New budget:  40097.98974180197
# This took 134.1142599582672 secs
# Final budget is:  40097.98974180197
# Money still held:  18688.78016090393

# %%
print('Total trades won', total_n_trades_won)
print('Total trades lost', total_n_trades_lost)
# Out:
# Total trades won 178
# Total trades lost 29

# %% [markdown]
# ## Buying at open of the next day
#
# Currently we used the close price as buy price for our stocks.

# %%
import backtest

# Trade Attributes
total_n_trades = 0
total_n_trades_won = 0
total_n_trades_lost = 0
total_sum_trades_won = 0
total_sum_trades_lost = 0

total_average_gain = 0
total_average_loss = 0
total_total_profit = 0

# list of stocks that should be bought at open the next day
to_buy = []
# dict of all currently held stocks
held = {}
# dict of all buys of one stock
bought = {}
# dict of all sells of one stock
sold = {}
# dict of all profits of one day
profit_per_day = {}
total_revenue = 0

bet_percent = 0.12
budget = 30000
#bet_size = backtest.calc_bet_size(budget, bet_percent)

start = time.time()
old_date = 0

for row in cleaned_data[X_train.shape[0]+1727987:,]:
#for row in cleaned_data[-250000:,]:
#for row in test_t:
    ticker, date = row[0], row[1]
    
    if ticker not in sp500_tickers:
        continue
    
    data = row[2:-1] #2 if adj close should be incoperated
    bet_size = budget * bet_percent
    
    if ticker in to_buy:
        print("\nBought ", ticker, " at ", date, end=" ")
        n_shares, left_over_bet, budget = backtest.buy(share_price=data[4],
                                                      bet_size=bet_size, budget = budget)
        held[ticker] = (n_shares, data)
        to_buy.remove(ticker)
        print("for {} n shares with per share price: {:4f}, totaling: {:4f}".format(n_shares, data[4],
                                                                                    n_shares*data[4]))
        print("New budget is: ", budget)
        
        
    #if old_date != date:
        #print("\n###################\n     One day takes", time.time()-start)
        #print("################")
    old_date = date
    
    # Before buying, make sure ticker is not already bought
    # If already bought, check for a sell signal
    if ticker in held.keys():
        n_shares, held_data = held[ticker]

        # held_data[1] is close price
        if backtest.is_sell(held_data[1], data[1]):
            _, negative = backtest.is_sell(held_data[1], data[1]) # change two lines so you only need function call once
            revenue, profit, budget = backtest.sell(entry_ticker_close=held_data[1], cur_ticker_close=data[1],
                                           n_shares=n_shares, budget=budget, neg=negative, perfect=False)

            if negative:
                total_n_trades_lost += 1
                total_sum_trades_lost -= profit
            else:
                total_n_trades_won += 1
                total_sum_trades_won += profit

            del held[ticker]
            print("\nSold {} at {} for a profit of {:4f} returning {} as revenue".format(ticker, date,
                                                                                         profit, revenue))
            print("New budget: ", budget)
            
    
    # buy ticker
    #ToDo maybe input lag in buying, say one stock thas has been sold cant be rebought for one month
    elif backtest.is_buy(data, forest): # shouldnt hit if ticker is sold the same day
        if budget > 10000:
            to_buy.append(ticker)
    
            
print("This took {} secs".format(time.time()-start))
print("Final budget is: ", budget)

money_held = 0
for n_shares, data in held.values():
    money_held += n_shares * data[1]
print("Money still held: ", money_held)
# Out:
# Bought  ENPH  at  2020-09-18 for 53 n shares with per share price: 67.720001, totaling: 3589.160065
# New budget is:  26410.83994
#
# Bought  ETSY  at  2020-09-18 for 28 n shares with per share price: 110.684998, totaling: 3099.179932
# New budget is:  23311.6600072
#
# Bought  MKTX  at  2020-09-21 for 6 n shares with per share price: 434.329987, totaling: 2605.979919
# New budget is:  20705.680086336
#
# Bought  AMD  at  2020-09-21 for 33 n shares with per share price: 74.230003, totaling: 2449.590111
# New budget is:  18256.08997597568
#
# Bought  MPWR  at  2020-09-21 for 8 n shares with per share price: 248.779999, totaling: 1990.239990
# New budget is:  16265.849988858597
#
# Bought  CDW  at  2020-09-22 for 18 n shares with per share price: 108.330002, totaling: 1949.940033
# New budget is:  14315.909960195566
#
# Bought  ILMN  at  2020-09-23 for 6 n shares with per share price: 274.700012, totaling: 1648.200073
# New budget is:  12667.709884972097
#
# Bought  KLAC  at  2020-09-23 for 8 n shares with per share price: 184.380005, totaling: 1475.040039
# New budget is:  11192.669848775446
#
# Bought  FITB  at  2020-09-23 for 66 n shares with per share price: 20.170000, totaling: 1331.220005
# New budget is:  9861.44984692239
#
# Bought  SIVB  at  2020-09-23 for 5 n shares with per share price: 232.619995, totaling: 1163.099976
# New budget is:  8698.349875291704
#
# Bought  TSLA  at  2020-09-24 for 2 n shares with per share price: 363.799988, totaling: 727.599976
# New budget is:  7970.749900256699
#
# Bought  NXPI  at  2020-09-24 for 8 n shares with per share price: 118.639999, totaling: 949.119995
# New budget is:  7021.629902225895
#
# Bought  SWKS  at  2020-09-24 for 6 n shares with per share price: 131.960007, totaling: 791.760040
# New budget is:  6229.869863958787
#
# Sold ENPH at 2020-09-29 for a profit of 398.454204 returning 4016.7640240000005 as revenue
# New budget:  10246.633887958787
#
# Bought  LKQ  at  2020-09-30 for 44 n shares with per share price: 27.799999, totaling: 1223.199966
# New budget is:  9023.433921403734
#
# Bought  EXC  at  2020-09-30 for 30 n shares with per share price: 35.650002, totaling: 1069.500046
# New budget is:  7953.933870835286
#
# Sold ETSY at 2020-10-01 for a profit of 334.992042 returning 3463.992042 as revenue
# New budget:  11417.925912835286
#
# Sold TSLA at 2020-10-01 for a profit of 72.443994 returning 848.024014 as revenue
# New budget:  12265.949926835287
#
# Bought  ENPH  at  2020-10-02 for 17 n shares with per share price: 85.610001, totaling: 1455.370010
# New budget is:  10810.579915615053
#
# Bought  XLNX  at  2020-10-05 for 12 n shares with per share price: 103.339996, totaling: 1240.079956
# New budget is:  9570.499955741248
#
# Sold ILMN at 2020-10-05 for a profit of 155.412048 returning 1793.412048 as revenue
# New budget:  11363.912003741249
#
# Sold FITB at 2020-10-05 for a profit of 126.324024 returning 1417.283984 as revenue
# New budget:  12781.195987741248
#
# Bought  APA  at  2020-10-05 for 153 n shares with per share price: 9.970000, totaling: 1525.410041
# New budget is:  11255.785949212297
#
# Bought  ALGN  at  2020-10-07 for 4 n shares with per share price: 320.399994, totaling: 1281.599976
# New budget is:  9974.18597530682
#
# Sold ENPH at 2020-10-07 for a profit of 177.377988 returning 1714.687998 as revenue
# New budget:  11688.87397330682
#
# Sold SIVB at 2020-10-07 for a profit of 119.730006 returning 1252.829986 as revenue
# New budget:  12941.70395930682
#
# Sold MKTX at 2020-10-07 for a profit of 242.028042 returning 2900.028042 as revenue
# New budget:  15841.73200130682
#
# Bought  IPGP  at  2020-10-07 for 10 n shares with per share price: 176.229996, totaling: 1762.299957
# New budget is:  14079.432041150001
#
# Bought  HSIC  at  2020-10-07 for 28 n shares with per share price: 59.169998, totaling: 1656.759949
# New budget is:  12422.672096212002
#
# Sold MPWR at 2020-10-07 for a profit of 203.280030 returning 2251.04004 as revenue
# New budget:  14673.712136212001
#
# Sold NXPI at 2020-10-09 for a profit of 107.375976 returning 1060.656006 as revenue
# New budget:  15734.368142212
#
# Sold KLAC at 2020-10-09 for a profit of 145.200000 returning 1591.51995 as revenue
# New budget:  17325.888092212
#
# Sold XLNX at 2020-10-09 for a profit of 116.640036 returning 1373.520006 as revenue
# New budget:  18699.408098212
#
# Sold APA at 2020-10-12 for a profit of -81.089960 returning 1424.43006 as revenue
# New budget:  20123.838158212
#
# Sold SWKS at 2020-10-12 for a profit of 78.804000 returning 890.00398 as revenue
# New budget:  21013.842138212
#
# Sold CDW at 2020-10-12 for a profit of 214.271958 returning 2197.331928 as revenue
# New budget:  23211.174066212
#
# Sold EXC at 2020-10-15 for a profit of 101.520060 returning 1174.3200100000001 as revenue
# New budget:  24385.494076212
#
# Sold LKQ at 2020-10-16 for a profit of 109.823994 returning 1329.943974 as revenue
# New budget:  25715.438050212
#
# Bought  SIVB  at  2020-10-20 for 11 n shares with per share price: 274.510010, totaling: 3019.610107
# New budget is:  22695.82794418656
#
# Bought  GRMN  at  2020-10-20 for 27 n shares with per share price: 98.330002, totaling: 2654.910049
# New budget is:  20040.91789088417
#
# Bought  GOOGL  at  2020-10-20 for 1 n shares with per share price: 1523.109985, totaling: 1523.109985
# New budget is:  18517.80790397807
#
# Bought  WYNN  at  2020-10-20 for 31 n shares with per share price: 70.160004, totaling: 2174.960114
# New budget is:  16342.847785500704
#
# Bought  ZBRA  at  2020-10-20 for 6 n shares with per share price: 293.239990, totaling: 1759.439941
# New budget is:  14583.40784124062
#
# Bought  XLNX  at  2020-10-21 for 15 n shares with per share price: 114.940002, totaling: 1724.100037
# New budget is:  12859.307800291746
#
# Bought  HOLX  at  2020-10-21 for 23 n shares with per share price: 66.559998, totaling: 1530.879944
# New budget is:  11328.427854256735
#
# Bought  TECH  at  2020-10-21 for 5 n shares with per share price: 265.260010, totaling: 1326.300049
# New budget is:  10002.127801745928
#
# Bought  BIIB  at  2020-10-21 for 4 n shares with per share price: 264.989990, totaling: 1059.959961
# New budget is:  8942.167845536416
#
# Bought  REG  at  2020-10-22 for 28 n shares with per share price: 37.160000, totaling: 1040.479996
# New budget is:  7901.687854072046
#
# Bought  UAL  at  2020-10-22 for 26 n shares with per share price: 35.900002, totaling: 933.400040
# New budget is:  6968.287811583401
#
# Bought  HST  at  2020-10-22 for 75 n shares with per share price: 11.080000, totaling: 830.999994
# New budget is:  6137.287814193393
#
# Bought  MTCH  at  2020-10-22 for 6 n shares with per share price: 117.669998, totaling: 706.019989
# New budget is:  5431.267826490187
#
# Bought  FFIV  at  2020-10-22 for 5 n shares with per share price: 127.470001, totaling: 637.350006
# New budget is:  4793.917817311365
#
# Sold ALGN at 2020-10-22 for a profit of 311.064036 returning 1605.544016 as revenue
# New budget:  6399.461833311365
#
# Bought  MAR  at  2020-10-22 for 7 n shares with per share price: 96.099998, totaling: 672.699989
# New budget is:  5726.7618433140005
#
# Bought  ENPH  at  2020-10-22 for 6 n shares with per share price: 102.260002, totaling: 613.560013
# New budget is:  5113.201832116321
#
# Bought  ZION  at  2020-10-22 for 20 n shares with per share price: 30.250000, totaling: 605.000000
# New budget is:  4508.201832262363
#
# Bought  EXPE  at  2020-10-22 for 5 n shares with per share price: 93.050003, totaling: 465.250015
# New budget is:  4042.9518123908792
#
# Bought  PFG  at  2020-10-22 for 11 n shares with per share price: 40.990002, totaling: 450.890018
# New budget is:  3592.061794903974
#
# Sold UAL at 2020-10-26 for a profit of -49.400040 returning 918.84 as revenue
# New budget:  4510.9017949039735
#
# Sold EXPE at 2020-10-27 for a profit of -29.850000 returning 475.35 as revenue
# New budget:  4986.251794903974
#
# Sold PFG at 2020-10-27 for a profit of -39.490000 returning 432.84998 as revenue
# New budget:  5419.101774903974
#
# Sold REG at 2020-10-27 for a profit of -54.879980 returning 1014.16003 as revenue
# New budget:  6433.261804903974
#
# Sold MAR at 2020-10-27 for a profit of -51.520010 returning 654.21999 as revenue
# New budget:  7087.481794903973
#
# Sold HST at 2020-10-27 for a profit of -46.500000 returning 814.49997 as revenue
# New budget:  7901.981764903973
#
# Sold BIIB at 2020-10-27 for a profit of -54.440000 returning 1021.20001 as revenue
# New budget:  8923.181774903973
# Sold ZION at 2020-10-28 for a profit of -32.999990 returning 612.00001 as revenue
# New budget:  9535.181784903973
#
# Sold ENPH at 2020-10-30 for a profit of -32.220010 returning 588.53998 as revenue
# New budget:  10123.721764903972
#
# Bought  DISH  at  2020-11-02 for 46 n shares with per share price: 26.000000, totaling: 1196.000000
# New budget is:  8927.721763115496
#
# Bought  ULTA  at  2020-11-02 for 5 n shares with per share price: 209.000000, totaling: 1045.000000
# New budget is:  7882.721761541637
#
# Bought  CSCO  at  2020-11-02 for 26 n shares with per share price: 36.189999, totaling: 940.939964
# New budget is:  6941.78180015664
#
# Bought  VRSK  at  2020-11-02 for 4 n shares with per share price: 180.509995, totaling: 722.039978
# New budget is:  6219.741824137843
#
# Bought  DISCK  at  2020-11-02 for 40 n shares with per share price: 18.480000, totaling: 739.199982
# New budget is:  5480.541845241301
#
# Bought  NWL  at  2020-11-02 for 36 n shares with per share price: 17.799999, totaling: 640.799973
# New budget is:  4839.741873812345
#
# Bought  LRCX  at  2020-11-02 for 1 n shares with per share price: 348.119995, totaling: 348.119995
# New budget is:  4491.621878954863
#
# Bought  MAR  at  2020-11-02 for 5 n shares with per share price: 93.000000, totaling: 465.000000
# New budget is:  4026.6218834802794
#
# Bought  BKNG  at  2020-11-02 for 0 n shares with per share price: 1653.500000, totaling: 0.000000
# New budget is:  4026.6218874626456
#
# Bought  QCOM  at  2020-11-02 for 3 n shares with per share price: 124.500000, totaling: 373.500000
# New budget is:  3653.121890967128
#
# Bought  STX  at  2020-11-02 for 9 n shares with per share price: 48.480000, totaling: 436.319996
# New budget is:  3216.801894051073
#
# Bought  TMUS  at  2020-11-02 for 3 n shares with per share price: 111.139999, totaling: 333.419998
# New budget is:  2883.381896764944
#
# Bought  QRVO  at  2020-11-02 for 2 n shares with per share price: 129.889999, totaling: 259.779999
# New budget is:  2623.6018991531505
#
# Bought  TSLA  at  2020-11-02 for 0 n shares with per share price: 394.000000, totaling: 0.000000
# New budget is:  2623.601901254772
#
# Bought  REG  at  2020-11-02 for 8 n shares with per share price: 35.880001, totaling: 287.040009
# New budget is:  2336.5618931041995
#
# Bought  FANG  at  2020-11-02 for 10 n shares with per share price: 26.450001, totaling: 264.500008
# New budget is:  2072.0618859316955
#
# Bought  NWS  at  2020-11-02 for 18 n shares with per share price: 13.110000, totaling: 235.979994
# New budget is:  1836.081889619892
#
# Bought  NWSA  at  2020-11-02 for 16 n shares with per share price: 13.310000, totaling: 212.960007
# New budget is:  1623.1218828655049
#
# Bought  CSX  at  2020-11-02 for 2 n shares with per share price: 80.330002, totaling: 160.660004
# New budget is:  1462.4618769216443
#
# Bought  UAL  at  2020-11-03 for 5 n shares with per share price: 34.320000, totaling: 171.599998
# New budget is:  1290.861881691047
#
# Bought  FISV  at  2020-11-03 for 1 n shares with per share price: 98.029999, totaling: 98.029999
# New budget is:  1192.8318858881216
#
# Bought  MU  at  2020-11-03 for 2 n shares with per share price: 50.130001, totaling: 100.260002
# New budget is:  1092.5718795815471
#
# Sold XLNX at 2020-11-04 for a profit of 152.639922 returning 1822.1399720000002 as revenue
# New budget:  2914.7118515815473
#
# Sold MTCH at 2020-11-05 for a profit of 65.700000 returning 766.0200100000001 as revenue
# New budget:  3680.7318615815475
#
# Sold TECH at 2020-11-05 for a profit of 128.400054 returning 1437.3999939999999 as revenue
# New budget:  5118.131855581547
#
# Sold FANG at 2020-11-05 for a profit of -15.099980 returning 262.00001 as revenue
# New budget:  5380.131865581547
#
# Sold HOLX at 2020-11-05 for a profit of 149.316000 returning 1663.8659599999999 as revenue
# New budget:  7043.997825581547
#
# Sold QCOM at 2020-11-05 for a profit of 38.592006 returning 410.50200599999994 as revenue
# New budget:  7454.4998315815465
#
# Sold ZBRA at 2020-11-05 for a profit of 163.044030 returning 1932.0239500000002 as revenue
# New budget:  9386.523781581547
#
# Sold GRMN at 2020-11-06 for a profit of 265.680030 returning 2933.0100500000003 as revenue
# New budget:  12319.533831581548
#
# Sold REG at 2020-11-06 for a profit of -17.200020 returning 272.39999 as revenue
# New budget:  12591.933821581548
#
# Sold QRVO at 2020-11-06 for a profit of 23.196006 returning 279.076006 as revenue
# New budget:  12871.009827581547
#
# Sold LRCX at 2020-11-06 for a profit of 35.082000 returning 386.03201 as revenue
# New budget:  13257.041837581548
#
# Bought  DLTR  at  2020-11-09 for 16 n shares with per share price: 97.959999, totaling: 1567.359985
# New budget is:  11689.681857071762
#
# Bought  ZION  at  2020-11-09 for 40 n shares with per share price: 35.000000, totaling: 1400.000000
# New budget is:  10289.68185422315
#
# Bought  PBCT  at  2020-11-09 for 107 n shares with per share price: 11.450000, totaling: 1225.149980
# New budget is:  9064.531871716372
#
# Sold WYNN at 2020-11-09 for a profit of 554.279910 returning 2799.9199900000003 as revenue
# New budget:  11864.451861716372
#
# Bought  FITB  at  2020-11-09 for 56 n shares with per share price: 25.200001, totaling: 1411.200043
# New budget is:  10453.251818310408
#
# Sold BKNG at 2020-11-09 for a profit of 0.000000 returning 0.0 as revenue
# New budget:  10453.251818310408
#
# Sold UAL at 2020-11-09 for a profit of 21.900000 returning 192.0 as revenue
# New budget:  10645.251818310408
#
# Sold FFIV at 2020-11-09 for a profit of 82.920000 returning 719.57001 as revenue
# New budget:  11364.821828310407
#
# Sold NWSA at 2020-11-09 for a profit of 22.848000 returning 235.488 as revenue
# New budget:  11600.309828310406
#
# Sold ULTA at 2020-11-09 for a profit of 109.259994 returning 1163.1599840000001 as revenue
# New budget:  12763.469812310406
#
# Sold IPGP at 2020-11-09 for a profit of 167.339994 returning 1931.8399639999998 as revenue
# New budget:  14695.309776310405
#
# Sold MAR at 2020-11-09 for a profit of 76.200006 returning 540.700016 as revenue
# New budget:  15236.009792310406
#
# Bought  VIAC  at  2020-11-09 for 59 n shares with per share price: 30.850000, totaling: 1820.150023
# New budget is:  13415.859767233158
#
# Sold NWS at 2020-11-09 for a profit of 28.512006 returning 265.93199599999997 as revenue
# New budget:  13681.791763233157
#
# Bought  EXPE  at  2020-11-09 for 13 n shares with per share price: 119.199997, totaling: 1549.599960
# New budget is:  12132.19180164518
#
# Bought  WBA  at  2020-11-09 for 36 n shares with per share price: 39.480000, totaling: 1421.279984
# New budget is:  10710.911815447758
#
# Bought  HBAN  at  2020-11-09 for 116 n shares with per share price: 11.020000, totaling: 1278.320053
# New budget is:  9432.591757594028
#
# Bought  VTRS  at  2020-11-09 for 73 n shares with per share price: 15.340000, totaling: 1119.820011
# New budget is:  8312.771746682745
#
# Bought  DISCA  at  2020-11-09 for 45 n shares with per share price: 21.860001, totaling: 983.700027
# New budget is:  7329.071717080817
#
# Bought  AAL  at  2020-11-09 for 61 n shares with per share price: 14.330000, totaling: 874.129995
# New budget is:  6454.9417210311185
#
# Sold SIVB at 2020-11-09 for a profit of 370.193976 returning 3405.644106 as revenue
# New budget:  9860.585827031118
#
# Sold AAL at 2020-11-10 for a profit of -50.019980 returning 755.18001 as revenue
# New budget:  10615.765837031118
#
# Bought  XLNX  at  2020-11-11 for 10 n shares with per share price: 124.370003, totaling: 1243.700027
# New budget is:  9372.065806587385
#
# Sold ZION at 2020-11-11 for a profit of -93.600000 returning 1489.60007 as revenue
# New budget:  10861.665876587385
#
# Sold DISH at 2020-11-11 for a profit of 125.028018 returning 1312.748008 as revenue
# New budget:  12174.413884587386
#
# Sold EXPE at 2020-11-11 for a profit of -116.220030 returning 1556.09996 as revenue
# New budget:  13730.513844587385
#
# Sold FITB at 2020-11-12 for a profit of -95.199940 returning 1392.16003 as revenue
# New budget:  15122.673874587384
#
# Bought  AAL  at  2020-11-12 for 151 n shares with per share price: 11.970000, totaling: 1807.470040
# New budget is:  13315.203829636897
#
# Bought  HST  at  2020-11-12 for 126 n shares with per share price: 12.660000, totaling: 1595.159981
# New budget is:  11720.043850080468
#
# Bought  CZR  at  2020-11-12 for 24 n shares with per share price: 57.400002, totaling: 1377.600037
# New budget is:  10342.443818070813
#
# Bought  FANG  at  2020-11-12 for 39 n shares with per share price: 31.799999, totaling: 1240.199970
# New budget is:  9102.243849902316
#
# Bought  WDC  at  2020-11-12 for 27 n shares with per share price: 40.279999, totaling: 1087.559967
# New budget is:  8014.683877914037
#
# Bought  AMAT  at  2020-11-12 for 13 n shares with per share price: 70.860001, totaling: 921.180008
# New budget is:  7093.503872564353
#
# Sold HBAN at 2020-11-12 for a profit of -76.559980 returning 1309.64 as revenue
# New budget:  8403.143872564353
# Sold CSCO at 2020-11-13 for a profit of 85.800000 returning 1019.20004 as revenue
# New budget:  9422.343912564353
#
# Bought  MRNA  at  2020-11-13 for 13 n shares with per share price: 86.620003, totaling: 1126.060036
# New budget is:  8296.283873056631
#
# Sold TMUS at 2020-11-13 for a profit of 32.111994 returning 363.281994 as revenue
# New budget:  8659.565867056632
#
# Bought  FOXA  at  2020-11-13 for 40 n shares with per share price: 25.950001, totaling: 1038.000031
# New budget is:  7621.565833009836
#
# Bought  PENN  at  2020-11-13 for 13 n shares with per share price: 65.349998, totaling: 849.549980
# New budget is:  6772.015853048655
#
# Bought  UAL  at  2020-11-13 for 21 n shares with per share price: 37.240002, totaling: 782.040035
# New budget is:  5989.975820682817
#
# Bought  DISH  at  2020-11-13 for 23 n shares with per share price: 30.469999, totaling: 700.809984
# New budget is:  5289.165832200879
#
# Bought  FOX  at  2020-11-13 for 24 n shares with per share price: 25.430000, totaling: 610.320007
# New budget is:  4678.845822336773
#
# Sold MU at 2020-11-16 for a profit of 12.936000 returning 115.09599999999999 as revenue
# New budget:  4793.941822336773
#
# Sold STX at 2020-11-16 for a profit of 39.797994 returning 476.927994 as revenue
# New budget:  5270.869816336773
#
# Sold DISCK at 2020-11-17 for a profit of 68.880018 returning 834.079988 as revenue
# New budget:  6104.949804336773
#
# Sold FANG at 2020-11-17 for a profit of 132.210036 returning 1366.950026 as revenue
# New budget:  7471.899830336773
#
# Sold HST at 2020-11-17 for a profit of 145.908024 returning 1684.368024 as revenue
# New budget:  9156.267854336773
#
# Sold TSLA at 2020-11-18 for a profit of 0.000000 returning 0.0 as revenue
# New budget:  9156.267854336773
#
# Sold VIAC at 2020-11-19 for a profit of 155.052042 returning 1869.0019920000002 as revenue
# New budget:  11025.269846336772
#
# Sold VTRS at 2020-11-19 for a profit of 130.962030 returning 1234.72202 as revenue
# New budget:  12259.991866336772
#
# Bought  NTAP  at  2020-11-20 for 28 n shares with per share price: 52.150002, totaling: 1460.200043
# New budget is:  10799.791822376359
#
# Bought  MU  at  2020-11-20 for 21 n shares with per share price: 61.480000, totaling: 1291.079990
# New budget is:  9508.711833691195
#
# Sold DISCA at 2020-11-20 for a profit of 90.989970 returning 1086.39001 as revenue
# New budget:  10595.101843691195
#
# Bought  APA  at  2020-11-20 for 111 n shares with per share price: 11.370000, totaling: 1262.069987
# New budget is:  9333.031852448252
#
# Sold WBA at 2020-11-20 for a profit of -81.000000 returning 1351.07996 as revenue
# New budget:  10684.111812448253
#
# Bought  LRCX  at  2020-11-20 for 2 n shares with per share price: 438.500000, totaling: 877.000000
# New budget is:  9807.111814954462
#
# Bought  ILMN  at  2020-11-23 for 3 n shares with per share price: 301.000000, totaling: 903.000000
# New budget is:  8904.111817159926
#
# Sold AAL at 2020-11-23 for a profit of 164.892054 returning 1937.632024 as revenue
# New budget:  10841.743841159927
#
# Bought  STX  at  2020-11-23 for 23 n shares with per share price: 56.110001, totaling: 1290.530014
# New budget is:  9551.213830220737
#
# Bought  WYNN  at  2020-11-23 for 12 n shares with per share price: 95.500000, totaling: 1146.000000
# New budget is:  8405.213830594248
#
# Sold AMAT at 2020-11-23 for a profit of 83.459976 returning 990.860016 as revenue
# New budget:  9396.073846594249
#
# Sold CZR at 2020-11-23 for a profit of 131.328042 returning 1518.0480120000002 as revenue
# New budget:  10914.121858594248
#
# Bought  ALGN  at  2020-11-23 for 2 n shares with per share price: 452.149994, totaling: 904.299988
# New budget is:  10009.821875562939
#
# Sold UAL at 2020-11-24 for a profit of 75.221964 returning 894.0120039999999 as revenue
# New budget:  10903.833879562939
#
# Sold DLTR at 2020-11-24 for a profit of 148.607964 returning 1682.528004 as revenue
# New budget:  12586.361883562939
#
# Sold WDC at 2020-11-24 for a profit of 105.785976 returning 1167.156016 as revenue
# New budget:  13753.51789956294
#
# Sold FISV at 2020-11-24 for a profit of 9.558000 returning 108.50799999999998 as revenue
# New budget:  13862.02589956294
#
# Sold DISH at 2020-11-24 for a profit of 67.481994 returning 792.902014 as revenue
# New budget:  14654.927913562939
#
# Sold APA at 2020-11-24 for a profit of 173.160030 returning 1442.99998 as revenue
# New budget:  16097.927893562939
#
# Sold MRNA at 2020-11-25 for a profit of 154.362006 returning 1316.431996 as revenue
# New budget:  17414.35988956294
#
# Bought  TSLA  at  2020-11-25 for 3 n shares with per share price: 550.059998, totaling: 1650.179993
# New budget is:  15764.179892815388
#
# Sold GOOGL at 2020-11-27 for a profit of 141.564036 returning 1692.643996 as revenue
# New budget:  17456.823888815386
#
# Bought  ENPH  at  2020-11-27 for 14 n shares with per share price: 142.490005, totaling: 1994.860077
# New budget is:  15461.96381215754
#
# Bought  APA  at  2020-11-27 for 131 n shares with per share price: 14.130000, totaling: 1851.030015
# New budget is:  13610.933794698636
#
# Bought  WDC  at  2020-11-27 for 36 n shares with per share price: 45.290001, totaling: 1630.440033
# New budget is:  11980.4937593348
#
# Bought  EA  at  2020-11-27 for 11 n shares with per share price: 123.580002, totaling: 1359.380020
# New budget is:  10621.113738214624
#
# Bought  FANG  at  2020-11-30 for 29 n shares with per share price: 42.810001, totaling: 1241.490040
# New budget is:  9379.62369962887
#
# Sold AMD at 2020-11-30 for a profit of 291.456024 returning 2863.476104 as revenue
# New budget:  12243.09980362887
#
# Bought  AAL  at  2020-11-30 for 98 n shares with per share price: 14.920000, totaling: 1462.160007
# New budget is:  10780.939797193405
#
# Sold APA at 2020-11-30 for a profit of -134.929970 returning 1688.59004 as revenue
# New budget:  12469.529837193404
#
# Bought  MRNA  at  2020-11-30 for 10 n shares with per share price: 144.000000, totaling: 1440.000000
# New budget is:  11029.529836730197
#
# Bought  ETSY  at  2020-12-01 for 8 n shares with per share price: 161.509995, totaling: 1292.079956
# New budget is:  9737.449876322573
#
# Sold ENPH at 2020-12-01 for a profit of -163.939880 returning 1803.90009 as revenue
# New budget:  11541.349966322574
#
# Sold MRNA at 2020-12-01 for a profit of -117.300100 returning 1410.09995 as revenue
# New budget:  12951.449916322574
#
# Sold XLNX at 2020-12-02 for a profit of 120.300018 returning 1390.899998 as revenue
# New budget:  14342.349914322574
#
# Bought  NLOK  at  2020-12-02 for 94 n shares with per share price: 18.219999, totaling: 1712.679935
# New budget is:  12629.669974603867
#
# Bought  APA  at  2020-12-02 for 122 n shares with per share price: 12.330000, totaling: 1504.259991
# New budget is:  11125.409987651403
#
# Bought  FTNT  at  2020-12-03 for 10 n shares with per share price: 123.639999, totaling: 1236.399994
# New budget is:  9889.009989133234
#
# Sold NWL at 2020-12-03 for a profit of 61.776018 returning 742.536008 as revenue
# New budget:  10631.545997133235
#
# Bought  ENPH  at  2020-12-03 for 9 n shares with per share price: 129.500000, totaling: 1165.500000
# New budget is:  9466.045997477246
#
# Sold AAL at 2020-12-04 for a profit of 133.475970 returning 1518.21598 as revenue
# New budget:  10984.261977477247
#
# Sold APA at 2020-12-04 for a profit of 151.524048 returning 1750.944008 as revenue
# New budget:  12735.205985477247
#
# Sold FANG at 2020-12-04 for a profit of 126.324042 returning 1285.164012 as revenue
# New budget:  14020.369997477246
#
# Sold MU at 2020-12-04 for a profit of 150.443934 returning 1439.843964 as revenue
# New budget:  15460.213961477246
#
# Sold HSIC at 2020-12-04 for a profit of 150.527988 returning 1815.407958 as revenue
# New budget:  17275.621919477246
#
# Sold LRCX at 2020-12-04 for a profit of 79.607994 returning 946.888024 as revenue
# New budget:  18222.509943477246
#
# Sold NTAP at 2020-12-04 for a profit of 136.080042 returning 1589.000022 as revenue
# New budget:  19811.509965477246
#
# Sold WYNN at 2020-12-04 for a profit of 129.743976 returning 1275.504016 as revenue
# New budget:  21087.013981477245
#
# Sold ILMN at 2020-12-04 for a profit of 87.857994 returning 993.408014 as revenue
# New budget:  22080.421995477245
#
# Sold PENN at 2020-12-08 for a profit of 107.405976 returning 952.4059760000001 as revenue
# New budget:  23032.827971477247
#
# Bought  ABMD  at  2020-12-10 for 10 n shares with per share price: 265.679993, totaling: 2656.799927
# New budget is:  20376.028044899977
#
# Bought  MPWR  at  2020-12-10 for 7 n shares with per share price: 307.390015, totaling: 2151.730103
# New budget is:  18224.29793951198
# Bought  CDNS  at  2020-12-10 for 19 n shares with per share price: 114.690002, totaling: 2179.110046
# New budget is:  16045.187896770543
#
# Bought  PYPL  at  2020-12-10 for 9 n shares with per share price: 208.360001, totaling: 1875.240005
# New budget is:  14169.947889158078
#
# Bought  PENN  at  2020-12-11 for 22 n shares with per share price: 75.370003, totaling: 1658.140060
# New budget is:  12511.807832459108
#
# Sold WDC at 2020-12-15 for a profit of 166.968072 returning 1817.568022 as revenue
# New budget:  14329.375854459107
#
# Bought  AAL  at  2020-12-15 for 101 n shares with per share price: 16.990000, totaling: 1715.989977
# New budget is:  12613.385881924014
#
# Sold ENPH at 2020-12-15 for a profit of 177.066048 returning 1326.096028 as revenue
# New budget:  13939.481909924014
#
# Sold STX at 2020-12-15 for a profit of 125.028072 returning 1434.188032 as revenue
# New budget:  15373.669941924014
#
# Sold ETSY at 2020-12-16 for a profit of 132.815988 returning 1370.1759780000002 as revenue
# New budget:  16743.845919924013
#
# Sold PENN at 2020-12-16 for a profit of 188.892066 returning 1826.1320259999998 as revenue
# New budget:  18569.977945924013
#
# Bought  SIVB  at  2020-12-17 for 6 n shares with per share price: 359.269989, totaling: 2155.619934
# New budget is:  16414.35801241313
#
# Bought  DISCK  at  2020-12-17 for 77 n shares with per share price: 25.430000, totaling: 1958.110023
# New budget is:  14456.247990923555
#
# Bought  ZION  at  2020-12-17 for 41 n shares with per share price: 41.919998, totaling: 1718.719925
# New budget is:  12737.528062012729
#
# Bought  FITB  at  2020-12-18 for 56 n shares with per share price: 27.170000, totaling: 1521.520004
# New budget is:  11216.0080545712
#
# Bought  HBAN  at  2020-12-18 for 109 n shares with per share price: 12.340000, totaling: 1345.060017
# New budget is:  9870.948038022658
#
# Sold FTNT at 2020-12-18 for a profit of 118.560060 returning 1379.4600200000002 as revenue
# New budget:  11250.408058022658
#
# Sold TSLA at 2020-12-18 for a profit of 217.800000 returning 1939.8 as revenue
# New budget:  13190.208058022657
#
# Bought  DISCA  at  2020-12-18 for 56 n shares with per share price: 28.000000, totaling: 1568.000000
# New budget is:  11622.208061059939
#
# Sold AAL at 2020-12-21 for a profit of -91.909980 returning 1626.10004 as revenue
# New budget:  13248.308101059938
#
# Sold DISCK at 2020-12-21 for a profit of -99.329920 returning 1849.54004 as revenue
# New budget:  15097.848141059938
#
# Bought  ENPH  at  2020-12-21 for 11 n shares with per share price: 162.949997, totaling: 1792.449966
# New budget is:  13305.398174132746
#
# Bought  TSLA  at  2020-12-22 for 2 n shares with per share price: 648.000000, totaling: 1296.000000
# New budget is:  12009.398173236816
#
# Bought  APA  at  2020-12-22 for 97 n shares with per share price: 14.840000, totaling: 1439.480015
# New budget is:  10569.918162448397
#
# Sold MPWR at 2020-12-22 for a profit of 196.518036 returning 2347.407956 as revenue
# New budget:  12917.326118448396
#
# Bought  VIAC  at  2020-12-22 for 44 n shares with per share price: 34.880001, totaling: 1534.720047
# New budget is:  11382.606074234589
#
# Bought  EXPE  at  2020-12-22 for 11 n shares with per share price: 124.080002, totaling: 1364.880020
# New budget is:  10017.726055326439
#
# Bought  WBA  at  2020-12-22 for 29 n shares with per share price: 40.599998, totaling: 1177.399956
# New budget is:  8840.326098687266
#
# Bought  DISCK  at  2020-12-23 for 44 n shares with per share price: 23.969999, totaling: 1054.679970
# New budget is:  7785.646126844795
#
# Bought  INTC  at  2020-12-23 for 20 n shares with per share price: 46.169998, totaling: 923.399963
# New budget is:  6862.246161623419
#
# Bought  TER  at  2020-12-23 for 6 n shares with per share price: 119.070000, totaling: 714.419998
# New budget is:  6147.826162228608
#
# Sold ABMD at 2020-12-28 for a profit of 269.880066 returning 2949.179996 as revenue
# New budget:  9097.006158228607
#
# Sold CDNS at 2020-12-30 for a profit of 202.920036 returning 2434.469976 as revenue
# New budget:  11531.476134228607
#
# Bought  FANG  at  2020-12-31 for 28 n shares with per share price: 49.000000, totaling: 1372.000000
# New budget is:  10159.476138121174
#
# Sold EA at 2020-12-31 for a profit of 128.238054 returning 1494.1080339999999 as revenue
# New budget:  11653.584172121173
#
# Bought  MRNA  at  2020-12-31 for 12 n shares with per share price: 110.550003, totaling: 1326.600037
# New budget is:  10326.984131466632
#
# Bought  AMAT  at  2021-01-04 for 14 n shares with per share price: 87.239998, totaling: 1221.359970
# New budget is:  9105.624165690635
#
# Bought  NWL  at  2021-01-04 for 50 n shares with per share price: 21.780001, totaling: 1089.000034
# New budget is:  8016.624135807759
#
# Bought  PENN  at  2021-01-04 for 11 n shares with per share price: 85.260002, totaling: 937.860023
# New budget is:  7078.764109510827
#
# Bought  GILD  at  2021-01-04 for 14 n shares with per share price: 58.669998, totaling: 821.379974
# New budget is:  6257.384136369528
#
# Bought  IPGP  at  2021-01-04 for 3 n shares with per share price: 223.910004, totaling: 671.730011
# New budget is:  5585.654130005185
#
# Sold DISCK at 2021-01-06 for a profit of 122.759988 returning 1216.160008 as revenue
# New budget:  6801.814138005185
#
# Sold FOX at 2021-01-06 for a profit of 75.600000 returning 704.63998 as revenue
# New budget:  7506.454118005185
#
# Sold ENPH at 2021-01-06 for a profit of 215.160036 returning 2093.740026 as revenue
# New budget:  9600.194144005185
#
# Sold APA at 2021-01-06 for a profit of 158.304012 returning 1527.9440020000002 as revenue
# New budget:  11128.138146005185
#
# Sold FOXA at 2021-01-06 for a profit of 128.999952 returning 1194.399962 as revenue
# New budget:  12322.538108005185
#
# Sold ZION at 2021-01-06 for a profit of 163.343982 returning 1880.013942 as revenue
# New budget:  14202.552050005184
#
# Sold FANG at 2021-01-06 for a profit of 133.055970 returning 1488.25601 as revenue
# New budget:  15690.808060005184
#
# Sold TSLA at 2021-01-06 for a profit of 138.767946 returning 1419.4479959999999 as revenue
# New budget:  17110.256056005182
#
# Sold EXPE at 2021-01-06 for a profit of 133.781976 returning 1488.431996 as revenue
# New budget:  18598.68805200518
#
# Sold VIAC at 2021-01-06 for a profit of 140.184036 returning 1675.3440060000003 as revenue
# New budget:  20274.03205800518
#
# Sold DISCA at 2021-01-06 for a profit of 216.720024 returning 1773.519984 as revenue
# New budget:  22047.55204200518
#
# Sold FITB at 2021-01-07 for a profit of 161.616048 returning 1652.895998 as revenue
# New budget:  23700.44804000518
#
# Sold ALGN at 2021-01-07 for a profit of 98.136000 returning 1051.2959700000001 as revenue
# New budget:  24751.74401000518
#
# Bought  AKAM  at  2021-01-07 for 29 n shares with per share price: 102.000000, totaling: 2958.000000
# New budget is:  21793.74400880456
#
# Bought  REGN  at  2021-01-07 for 5 n shares with per share price: 471.239990, totaling: 2356.199951
# New budget is:  19437.544057748015
#
# Sold SIVB at 2021-01-07 for a profit of 239.328042 returning 2428.487952 as revenue
# New budget:  21866.032009748014
#
# Sold CSX at 2021-01-07 for a profit of 14.724000 returning 178.244 as revenue
# New budget:  22044.276009748013
#
# Sold WBA at 2021-01-07 for a profit of 104.225964 returning 1243.055974 as revenue
# New budget:  23287.331983748012
#
# Bought  ETSY  at  2021-01-07 for 16 n shares with per share price: 170.300003, totaling: 2724.800049
# New budget is:  20562.531935698247
#
# Bought  NFLX  at  2021-01-07 for 4 n shares with per share price: 508.279999, totaling: 2033.119995
# New budget is:  18529.411943414456
#
# Sold HBAN at 2021-01-07 for a profit of 134.069946 returning 1484.579986 as revenue
# New budget:  20013.991929414457
#
# Bought  VIAC  at  2021-01-08 for 60 n shares with per share price: 40.009998, totaling: 2400.599899
# New budget is:  17613.39202788472
#
# Bought  FFIV  at  2021-01-08 for 10 n shares with per share price: 193.720001, totaling: 1937.200012
# New budget is:  15676.192014538556
#
# Bought  DISCA  at  2021-01-08 for 54 n shares with per share price: 34.360001, totaling: 1855.440033
# New budget is:  13820.751982793929
#
# Bought  STX  at  2021-01-08 for 27 n shares with per share price: 60.709999, totaling: 1639.169975
# New budget is:  12181.582004858657
#
# Sold PENN at 2021-01-08 for a profit of 84.876006 returning 974.665996 as revenue
# New budget:  13156.248000858657
# Bought  LRCX  at  2021-01-11 for 3 n shares with per share price: 495.519989, totaling: 1486.559967
# New budget is:  11669.688030755618
#
# Bought  ILMN  at  2021-01-11 for 3 n shares with per share price: 379.649994, totaling: 1138.949982
# New budget is:  10530.738047064944
#
# Sold TER at 2021-01-11 for a profit of 66.383982 returning 769.943992 as revenue
# New budget:  11300.682039064945
#
# Bought  AAL  at  2021-01-11 for 91 n shares with per share price: 14.820000, totaling: 1348.619972
# New budget is:  9952.06206437715
#
# Sold MRNA at 2021-01-12 for a profit of 144.576018 returning 1398.216028 as revenue
# New budget:  11350.278092377152
#
# Sold AMAT at 2021-01-12 for a profit of 110.375994 returning 1326.556034 as revenue
# New budget:  12676.83412637715
#
# Sold ETSY at 2021-01-12 for a profit of 329.856006 returning 3062.495896 as revenue
# New budget:  15739.330022377151
#
# Bought  DISCK  at  2021-01-13 for 62 n shares with per share price: 30.070000, totaling: 1864.339981
# New budget is:  13874.990039691893
#
# Bought  SWKS  at  2021-01-13 for 10 n shares with per share price: 158.000000, totaling: 1580.000000
# New budget is:  12294.990034928865
#
# Sold INTC at 2021-01-13 for a profit of 124.560018 returning 1055.9600079999998 as revenue
# New budget:  13350.950042928866
#
# Bought  FOXA  at  2021-01-14 for 53 n shares with per share price: 30.180000, totaling: 1599.540016
# New budget is:  11751.410027777403
#
# Sold PBCT at 2021-01-14 for a profit of 123.905958 returning 1490.296008 as revenue
# New budget:  13241.706035777403
#
# Bought  WDC  at  2021-01-14 for 32 n shares with per share price: 49.560001, totaling: 1585.920044
# New budget is:  11655.785991484114
#
# Bought  MRNA  at  2021-01-14 for 11 n shares with per share price: 122.800003, totaling: 1350.800034
# New budget is:  10304.98596250602
#
# Bought  GOOG  at  2021-01-15 for 0 n shares with per share price: 1738.189941, totaling: 0.000000
# New budget is:  10304.985967005297
#
# Sold IPGP at 2021-01-19 for a profit of 72.665964 returning 727.2959840000001 as revenue
# New budget:  11032.281951005298
#
# Bought  PENN  at  2021-01-19 for 13 n shares with per share price: 101.110001, totaling: 1314.430008
# New budget is:  9717.851946884663
#
# Bought  GOOGL  at  2021-01-20 for 0 n shares with per share price: 1826.369995, totaling: 0.000000
# New budget is:  9717.851943258504
#
# Sold NFLX at 2021-01-20 for a profit of 185.880030 returning 2221.44009 as revenue
# New budget:  11939.292033258504
#
# Sold PYPL at 2021-01-21 for a profit of 179.820012 returning 2117.879982 as revenue
# New budget:  14057.172015258504
#
# Bought  NWS  at  2021-01-22 for 90 n shares with per share price: 18.629999, totaling: 1676.699924
# New budget is:  12380.472093427483
#
# Bought  NWSA  at  2021-01-22 for 77 n shares with per share price: 19.120001, totaling: 1472.240065
# New budget is:  10908.232032216185
#
# Bought  MTCH  at  2021-01-25 for 9 n shares with per share price: 141.589996, totaling: 1274.309967
# New budget is:  9633.922068350243
#
# Sold NWL at 2021-01-25 for a profit of 113.700030 returning 1199.1999799999999 as revenue
# New budget:  10833.122048350242
#
# Sold VIAC at 2021-01-25 for a profit of 275.399922 returning 2679.0000019999998 as revenue
# New budget:  13512.12205035024
#
# Bought  CDW  at  2021-01-25 for 11 n shares with per share price: 135.820007, totaling: 1494.020081
# New budget is:  12018.101974308212
#
# Bought  ALGN  at  2021-01-25 for 2 n shares with per share price: 533.390015, totaling: 1066.780029
# New budget is:  10951.321947391227
#
# Sold DISCA at 2021-01-26 for a profit of 197.316006 returning 2067.3360660000003 as revenue
# New budget:  13018.658013391227
#
# Sold MRNA at 2021-01-26 for a profit of 146.585946 returning 1573.505956 as revenue
# New budget:  14592.163969391226
#
# Bought  FANG  at  2021-01-27 for 30 n shares with per share price: 57.759998, totaling: 1732.799950
# New budget is:  12859.364023064278
#
# Bought  TECH  at  2021-01-27 for 4 n shares with per share price: 336.369995, totaling: 1345.479980
# New budget is:  11513.884040296565
#
# Sold AKAM at 2021-01-27 for a profit of 306.762084 returning 3288.2520139999997 as revenue
# New budget:  14802.136054296565
#
# Sold MTCH at 2021-01-27 for a profit of -70.829950 returning 1183.95003 as revenue
# New budget:  15986.086084296565
#
# Bought  PYPL  at  2021-01-27 for 8 n shares with per share price: 234.699997, totaling: 1877.599976
# New budget is:  14108.486104180976
#
# Bought  ZBRA  at  2021-01-27 for 4 n shares with per share price: 392.989990, totaling: 1571.959961
# New budget is:  12536.52614167926
#
# Bought  APA  at  2021-01-27 for 100 n shares with per share price: 15.020000, totaling: 1502.000046
# New budget is:  11034.526094677749
#
# Sold ALGN at 2021-01-27 for a profit of -59.659910 returning 1019.28003 as revenue
# New budget:  12053.806124677749
#
# Sold STX at 2021-01-27 for a profit of 206.064018 returning 1799.064018 as revenue
# New budget:  13852.870142677748
#
# Sold ILMN at 2021-01-27 for a profit of 107.279958 returning 1224.7199880000003 as revenue
# New budget:  15077.590130677749
#
# Bought  ANSS  at  2021-01-28 for 5 n shares with per share price: 353.359985, totaling: 1766.799927
# New budget is:  13310.790204996418
#
# Bought  WYNN  at  2021-01-28 for 15 n shares with per share price: 102.099998, totaling: 1531.499977
# New budget is:  11779.290230396848
#
# Bought  CZR  at  2021-01-28 for 20 n shares with per share price: 68.000000, totaling: 1360.000000
# New budget is:  10419.290232749227
#
# Bought  SIVB  at  2021-01-28 for 2 n shares with per share price: 456.619995, totaling: 913.239990
# New budget is:  9506.050244819318
#
# Sold AAL at 2021-01-28 for a profit of 169.260018 returning 1534.260018 as revenue
# New budget:  11040.31026281932
#
# Bought  AMAT  at  2021-01-28 for 13 n shares with per share price: 101.190002, totaling: 1315.470032
# New budget is:  9724.840231281001
#
# Bought  NXPI  at  2021-01-28 for 7 n shares with per share price: 166.529999, totaling: 1165.709991
# New budget is:  8559.130243527281
#
# Bought  PTC  at  2021-01-28 for 7 n shares with per share price: 133.899994, totaling: 937.299957
# New budget is:  7621.830284304008
#
# Bought  DXCM  at  2021-01-28 for 2 n shares with per share price: 353.290009, totaling: 706.580017
# New budget is:  6915.250270187527
#
# Bought  ZION  at  2021-01-28 for 18 n shares with per share price: 44.730000, totaling: 805.139992
# New budget is:  6110.110277765025
#
# Bought  MCHP  at  2021-01-28 for 5 n shares with per share price: 136.880005, totaling: 684.400024
# New budget is:  5425.710254433222
#
# Bought  INTC  at  2021-01-28 for 11 n shares with per share price: 54.790001, totaling: 602.690010
# New budget is:  4823.0202439012355
#
# Bought  ENPH  at  2021-01-28 for 3 n shares with per share price: 182.850006, totaling: 548.550018
# New budget is:  4274.470224633087
#
# Bought  BKNG  at  2021-01-28 for 0 n shares with per share price: 1979.040039, totaling: 0.000000
# New budget is:  4274.470227677117
#
# Bought  NVDA  at  2021-01-28 for 0 n shares with per share price: 519.849976, totaling: 0.000000
# New budget is:  4274.470230355862
#
# Bought  EXPE  at  2021-01-28 for 4 n shares with per share price: 126.379997, totaling: 505.519989
# New budget is:  3768.950242713159
#
# Sold LRCX at 2021-01-29 for a profit of -97.589900 returning 1451.85004 as revenue
# New budget:  5220.800282713159
#
# Sold ENPH at 2021-01-29 for a profit of -34.170000 returning 547.05002 as revenue
# New budget:  5767.850302713158
#
# Bought  ILMN  at  2021-01-29 for 1 n shares with per share price: 435.730011, totaling: 435.730011
# New budget is:  5332.120296387579
#
# Sold NLOK at 2021-02-01 for a profit of 160.740024 returning 1908.200034 as revenue
# New budget:  7240.32033038758
#
# Sold SWKS at 2021-02-01 for a profit of 167.399964 returning 1746.299954 as revenue
# New budget:  8986.62028438758
#
# Sold TECH at 2021-02-02 for a profit of 139.992042 returning 1413.7120120000002 as revenue
# New budget:  10400.33229638758
#
# Bought  LRCX  at  2021-02-03 for 2 n shares with per share price: 520.099976, totaling: 1040.199951
# New budget is:  9360.13234082107
#
# Bought  MAR  at  2021-02-03 for 9 n shares with per share price: 122.000000, totaling: 1098.000000
# New budget is:  8262.132339922542
#
# Sold GOOG at 2021-02-03 for a profit of 0.000000 returning 0.0 as revenue
# New budget:  8262.132339922542
#
# Bought  DISCA  at  2021-02-03 for 24 n shares with per share price: 40.540001, totaling: 972.960022
# New budget is:  7289.172319131837
# Sold FANG at 2021-02-04 for a profit of 157.679970 returning 1855.3799699999997 as revenue
# New budget:  9144.552289131836
#
# Sold PYPL at 2021-02-04 for a profit of 194.351952 returning 2033.8719720000001 as revenue
# New budget:  11178.424261131837
#
# Bought  VIAC  at  2021-02-04 for 26 n shares with per share price: 50.340000, totaling: 1308.840004
# New budget is:  9869.584259796016
#
# Sold WDC at 2021-02-04 for a profit of 170.687988 returning 1782.527958 as revenue
# New budget:  11652.112217796017
#
# Bought  HST  at  2021-02-04 for 97 n shares with per share price: 14.320000, totaling: 1389.039970
# New budget is:  10263.072251660495
#
# Sold PENN at 2021-02-04 for a profit of 139.775982 returning 1445.2359620000002 as revenue
# New budget:  11708.308213660495
#
# Bought  AAL  at  2021-02-05 for 79 n shares with per share price: 17.600000, totaling: 1390.400030
# New budget is:  10317.908188021236
#
# Bought  TSCO  at  2021-02-05 for 8 n shares with per share price: 146.220001, totaling: 1169.760010
# New budget is:  9148.148175458688
#
# Bought  KHC  at  2021-02-05 for 32 n shares with per share price: 33.330002, totaling: 1066.560059
# New budget is:  8081.588114403645
#
# Sold DISCK at 2021-02-08 for a profit of 195.300000 returning 2163.8 as revenue
# New budget:  10245.388114403646
#
# Sold WYNN at 2021-02-08 for a profit of 138.240000 returning 1668.9900499999999 as revenue
# New budget:  11914.378164403646
#
# Sold NWS at 2021-02-08 for a profit of 170.639994 returning 1812.239974 as revenue
# New budget:  13726.618138403646
#
# Sold NWSA at 2021-02-08 for a profit of 144.606048 returning 1574.496028 as revenue
# New budget:  15301.114166403646
#
# Sold APA at 2021-02-08 for a profit of 194.399988 returning 1654.4000279999998 as revenue
# New budget:  16955.514194403644
#
# Bought  PBCT  at  2021-02-09 for 136 n shares with per share price: 14.870000, totaling: 2022.319984
# New budget is:  14933.194211075208
#
# Bought  UAL  at  2021-02-09 for 40 n shares with per share price: 44.060001, totaling: 1762.400055
# New budget is:  13170.794155746182
#
# Bought  CINF  at  2021-02-10 for 18 n shares with per share price: 87.500000, totaling: 1575.000000
# New budget is:  11595.79415705664
#
# Sold CDW at 2021-02-10 for a profit of 145.926006 returning 1633.455956 as revenue
# New budget:  13229.25011305664
#
# Bought  APA  at  2021-02-10 for 91 n shares with per share price: 17.410000, totaling: 1584.309986
# New budget is:  11644.940129489843
#
# Sold EXPE at 2021-02-10 for a profit of 53.183994 returning 560.1439839999999 as revenue
# New budget:  12205.084113489844
#
# Bought  MU  at  2021-02-11 for 17 n shares with per share price: 84.400002, totaling: 1434.800026
# New budget is:  10770.284089871062
#
# Sold ZBRA at 2021-02-11 for a profit of 188.928006 returning 1754.367946 as revenue
# New budget:  12524.652035871062
#
# Bought  DISCK  at  2021-02-11 for 39 n shares with per share price: 38.150002, totaling: 1487.850060
# New budget is:  11036.801971566534
#
# Sold NXPI at 2021-02-11 for a profit of 124.613994 returning 1274.924004 as revenue
# New budget:  12311.725975566535
#
# Bought  WYNN  at  2021-02-11 for 12 n shares with per share price: 116.440002, totaling: 1397.280029
# New budget is:  10914.445948498551
#
# Sold NVDA at 2021-02-11 for a profit of 0.000000 returning 0.0 as revenue
# New budget:  10914.445948498551
#
# Bought  WDC  at  2021-02-11 for 20 n shares with per share price: 62.759998, totaling: 1255.199966
# New budget is:  9659.245984678724
#
# Sold DISCA at 2021-02-12 for a profit of 100.655970 returning 1080.096 as revenue
# New budget:  10739.341984678724
#
# Sold AMAT at 2021-02-12 for a profit of 121.289964 returning 1436.239984 as revenue
# New budget:  12175.581968678724
#
# Sold LRCX at 2021-02-12 for a profit of 98.195988 returning 1106.855958 as revenue
# New budget:  13282.437926678724
#
# Sold MCHP at 2021-02-12 for a profit of 62.700030 returning 755.9499999999999 as revenue
# New budget:  14038.387926678724
#
# Sold ILMN at 2021-02-12 for a profit of 46.992006 returning 473.43200600000006 as revenue
# New budget:  14511.819932678725
#
# Sold SIVB at 2021-02-16 for a profit of 87.828042 returning 991.7480220000001 as revenue
# New budget:  15503.567954678725
#
# Bought  FOX  at  2021-02-16 for 59 n shares with per share price: 31.510000, totaling: 1859.090014
# New budget is:  13644.477940117278
#
# Sold VIAC at 2021-02-17 for a profit of 139.463976 returning 1493.024016 as revenue
# New budget:  15137.501956117278
#
# Bought  DISCA  at  2021-02-17 for 38 n shares with per share price: 47.080002, totaling: 1789.040070
# New budget is:  13348.461891383204
#
# Bought  FANG  at  2021-02-18 for 23 n shares with per share price: 68.230003, totaling: 1569.290077
# New budget is:  11779.17181441722
#
# Sold KHC at 2021-02-18 for a profit of 99.071994 returning 1180.671974 as revenue
# New budget:  12959.84378841722
#
# Sold HST at 2021-02-19 for a profit of 151.901982 returning 1522.5119920000002 as revenue
# New budget:  14482.35578041722
#
# Bought  VIAC  at  2021-02-19 for 27 n shares with per share price: 62.180000, totaling: 1678.860008
# New budget is:  12803.495776767153
#
# Sold DISCK at 2021-02-22 for a profit of 163.800000 returning 1684.8 as revenue
# New budget:  14488.295776767152
#
# Sold AAL at 2021-02-22 for a profit of 154.050000 returning 1512.0600399999998 as revenue
# New budget:  16000.355816767153
#
# Sold PBCT at 2021-02-22 for a profit of 243.984060 returning 2288.06402 as revenue
# New budget:  18288.419836767152
#
# Sold BKNG at 2021-02-22 for a profit of 0.000000 returning 0.0 as revenue
# New budget:  18288.419836767152
#
# Sold ZION at 2021-02-22 for a profit of 88.452024 returning 901.511994 as revenue
# New budget:  19189.931830767153
#
# Sold MAR at 2021-02-22 for a profit of 103.733994 returning 1213.8839839999998 as revenue
# New budget:  20403.815814767153
#
# Sold WYNN at 2021-02-23 for a profit of 157.679958 returning 1532.639978 as revenue
# New budget:  21936.455792767152
#
# Sold CZR at 2021-02-23 for a profit of 144.359982 returning 1619.159942 as revenue
# New budget:  23555.61573476715
#
# Sold UAL at 2021-02-23 for a profit of 174.960018 returning 1907.760008 as revenue
# New budget:  25463.37574276715
#
# Bought  XRAY  at  2021-02-24 for 57 n shares with per share price: 53.009998, totaling: 3021.569904
# New budget is:  22441.80583363509
#
# Sold VRSK at 2021-02-24 for a profit of -58.479980 returning 670.12 as revenue
# New budget:  23111.92583363509
#
# Sold APA at 2021-02-24 for a profit of 174.719934 returning 1777.229994 as revenue
# New budget:  24889.15582763509
#
# Bought  ETSY  at  2021-02-24 for 14 n shares with per share price: 209.990005, totaling: 2939.860077
# New budget is:  21949.29574831888
#
# Bought  DISH  at  2021-02-24 for 84 n shares with per share price: 31.000000, totaling: 2604.000000
# New budget is:  19345.295748520613
#
# Bought  AAL  at  2021-02-25 for 104 n shares with per share price: 22.129999, totaling: 2301.519913
# New budget is:  17043.77583869814
#
# Sold ANSS at 2021-02-25 for a profit of -122.050020 returning 1692.29996 as revenue
# New budget:  18736.07579869814
#
# Bought  DISCK  at  2021-02-25 for 50 n shares with per share price: 44.130001, totaling: 2206.500053
# New budget is:  16529.575742854366
#
# Sold REGN at 2021-02-25 for a profit of -140.050050 returning 2265.95001 as revenue
# New budget:  18795.525752854366
#
# Sold ETSY at 2021-02-25 for a profit of -161.280060 returning 2766.12003 as revenue
# New budget:  21561.645782854364
#
# Bought  PENN  at  2021-02-26 for 22 n shares with per share price: 115.250000, totaling: 2535.500000
# New budget is:  19026.14577891184
#
# Sold DISCA at 2021-03-01 for a profit of 201.095994 returning 2076.7760139999996 as revenue
# New budget:  21102.92179291184
#
# Bought  UAL  at  2021-03-01 for 45 n shares with per share price: 55.439999, totaling: 2494.799938
# New budget is:  18608.121857762417
#
# Bought  NWL  at  2021-03-02 for 92 n shares with per share price: 24.200001, totaling: 2226.400070
# New budget is:  16381.721784830926
#
# Bought  CMCSA  at  2021-03-02 for 36 n shares with per share price: 54.310001, totaling: 1955.160049
# New budget is:  14426.561730651214
#
# Bought  NWSA  at  2021-03-02 for 71 n shares with per share price: 24.340000, totaling: 1728.140011
# New budget is:  12698.421722973068
#
# Sold FOX at 2021-03-02 for a profit of 191.159982 returning 1999.509962 as revenue
# New budget:  14697.931684973068
#
# Sold FOXA at 2021-03-02 for a profit of 212.424012 returning 1869.7340319999998 as revenue
# New budget:  16567.665716973068
#
# Bought  APA  at  2021-03-02 for 103 n shares with per share price: 19.200001, totaling: 1977.600079
# New budget is:  14590.0656409363
# Sold DISCK at 2021-03-03 for a profit of 207.300000 returning 2381.80008 as revenue
# New budget:  16971.8657209363
#
# Bought  DISCA  at  2021-03-03 for 34 n shares with per share price: 59.209999, totaling: 2013.139969
# New budget is:  14958.725754423946
#
# Sold PTC at 2021-03-04 for a profit of -83.300010 returning 885.01 as revenue
# New budget:  15843.735754423946
#
# Bought  WBA  at  2021-03-04 for 39 n shares with per share price: 47.599998, totaling: 1856.399940
# New budget is:  13987.335813893073
#
# Sold FANG at 2021-03-04 for a profit of 222.456036 returning 1720.6760259999999 as revenue
# New budget:  15708.011839893072
#
# Sold PENN at 2021-03-04 for a profit of -151.579980 returning 2395.57999 as revenue
# New budget:  18103.59182989307
#
# Bought  DISCK  at  2021-03-05 for 41 n shares with per share price: 52.279999, totaling: 2143.479950
# New budget is:  15960.1118803059
#
# Sold APA at 2021-03-05 for a profit of 231.750000 returning 2240.25 as revenue
# New budget:  18200.3618803059
#
# Sold UAL at 2021-03-05 for a profit of -125.550040 returning 2273.40002 as revenue
# New budget:  20473.7619003059
#
# Bought  ENPH  at  2021-03-05 for 15 n shares with per share price: 153.679993, totaling: 2305.199890
# New budget is:  18168.56201226919
#
# Sold CINF at 2021-03-05 for a profit of 164.376012 returning 1767.096032 as revenue
# New budget:  19935.658044269192
#
# Sold VIAC at 2021-03-05 for a profit of 187.109988 returning 1879.739948 as revenue
# New budget:  21815.39799226919
#
# Sold ENPH at 2021-03-08 for a profit of -172.350090 returning 1980.89996 as revenue
# New budget:  23796.29795226919
#
# Bought  TSLA  at  2021-03-08 for 4 n shares with per share price: 600.549988, totaling: 2402.199951
# New budget is:  21394.097997996887
#
# Bought  NXPI  at  2021-03-09 for 14 n shares with per share price: 176.130005, totaling: 2465.820068
# New budget is:  18928.277928237258
#
# Sold TSLA at 2021-03-09 for a profit of 265.392042 returning 2517.392042 as revenue
# New budget:  21445.669970237257
#
# Bought  PENN  at  2021-03-09 for 22 n shares with per share price: 114.889999, totaling: 2527.579987
# New budget is:  18918.089983808786
#
# Bought  MRNA  at  2021-03-09 for 17 n shares with per share price: 127.110001, totaling: 2160.870010
# New budget is:  16757.219975751734
#
# Bought  PTC  at  2021-03-09 for 16 n shares with per share price: 122.330002, totaling: 1957.280029
# New budget is:  14799.939948661526
#
# Bought  APA  at  2021-03-10 for 81 n shares with per share price: 21.750000, totaling: 1761.750000
# New budget is:  13038.189944822143
#
# Bought  ENPH  at  2021-03-10 for 9 n shares with per share price: 158.009995, totaling: 1422.089951
# New budget is:  11616.099991443487
#
# Sold XRAY at 2021-03-11 for a profit of 282.834018 returning 3360.834018 as revenue
# New budget:  14976.934009443487
#
# Bought  TSLA  at  2021-03-11 for 2 n shares with per share price: 699.400024, totaling: 1398.800049
# New budget is:  13578.133958310267
#
# Sold DISCA at 2021-03-12 for a profit of 196.859952 returning 2286.1599819999997 as revenue
# New budget:  15864.293940310266
#
# Sold DISH at 2021-03-12 for a profit of 295.848042 returning 2933.4480120000003 as revenue
# New budget:  18797.741952310265
#
# Sold PENN at 2021-03-15 for a profit of 274.824000 returning 2819.12403 as revenue
# New budget:  21616.865982310264
#
# Sold WBA at 2021-03-15 for a profit of 191.645970 returning 2019.1859900000002 as revenue
# New budget:  23636.051972310266
#
# Bought  XRAY  at  2021-03-15 for 45 n shares with per share price: 62.759998, totaling: 2824.199924
# New budget is:  20811.852045633033
#
# Sold AAL at 2021-03-15 for a profit of 268.943970 returning 2438.3840299999997 as revenue
# New budget:  23250.236075633034
# This took 116.99945092201233 secs
# Final budget is:  23250.236075633034
# Money still held:  30320.559968948364

# %%
print('Total trades won', total_n_trades_won)
print('Total trades lost', total_n_trades_lost)
# Out:
# Total trades won 170
# Total trades lost 35
